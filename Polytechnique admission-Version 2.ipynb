# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import tabula.io as tabula
from IPython.display import display,HTML,Javascript
import ipywidgets as widgets
import regex as re
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
#from googlesearch import search
from lxml import etree
import time
from duckduckgo_search import ddg
import os  
from matplotlib import pyplot as plt

# Download NLTK resources if not already installed
nltk.download('punkt')
nltk.download('stopwords')

# Initialize Porter Stemmer and stopwords
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

# Load spaCy model and define preprocessing function
# nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Mahmud
# [nltk_data]     Hasan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Mahmud
# [nltk_data]     Hasan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Singapore Polytechnic (SP)

# %%
# Function to clean course URLs and extract descriptions
def url_course_desc_scrap(df):
    # Lists to store cleaned URLs and course descriptions
    course_descriptions = []
    career_prospects = []

    for index, row in df.iterrows():
        print(row['Course Name'])
        clean_url = row['Course URL']
        #cleaned_urls.append(clean_url)
        career_prospect = extract_career_prospects(clean_url)
        career_prospects.append(career_prospect)
        try:
            webpage = requests.get(clean_url)
            soup = BeautifulSoup(webpage.content, "html.parser")
            dom = etree.HTML(str(soup))
            # Define a regex pattern to match HTML tags
            html_tag_pattern = re.compile(r'<[^>]*>')
            # Use XPath to select the parent <p> element that contains the <strong> element
            paragraph_with_strong = dom.xpath('/html/body/form/div[4]/div/div[2]/div[2]/div/div[1]')

            if paragraph_with_strong:
                # Extract the text from the selected <p> element and its children
                paragraph_text = etree.tostring(paragraph_with_strong[0], method='html').decode()
                cleaned_text = re.sub(html_tag_pattern, '', paragraph_text)
                course_descriptions.append(cleaned_text)
                print("Success : course_descriptions ")
            else:
                course_descriptions.append("Course description was not found")
                print("Failed : course_descriptions ")
        except:
            course_descriptions.append("Course description was not found")
            print("Failed : course_descriptions ")            
                
    # Add the cleaned URLs and course descriptions to the DataFrame
    #df["Course URL"] = cleaned_urls
    df["Course Description"] = course_descriptions
    df["Career Prospect"] = career_prospects
    
# Function to extract career prospects using XPath
def extract_career_prospects(url):
           
    career_prospects = []
    # Split the URL by '/' and keep only the first 7 components

    clean_url = url + "/your-future"
    #print(clean_url)
    try: 
        webpage = requests.get(clean_url)
        dom = etree.HTML(webpage.text)

        # Use the full XPath to select the element containing career prospects
        career_prospects_elements = dom.xpath("/html/body/form/div[4]/div/div[2]/div[2]/div/div[1]/div/div")

        if career_prospects_elements:
            # Extract the text from the selected element
            career_prospects_text = ", ".join(career_prospects_elements[0].itertext())
            #print(career_prospects_text)
            career_prospects.append(career_prospects_text)
            print("Success : Career prospect ")
        else:
            career_prospects.append("No element Found")
            print("Failed  : Career Prsopect ")
            
        return ", ".join(career_prospects)
    except:
        print("Failed  : Career Prsopect ")
        return "No element Found"
    
def sp_scrap():
    try:
        # URL of the website to scrape
        url = "https://www.sp.edu.sg/sp/admissions/admissions-exercises/admission-criteria/course-intake-and-jae-elr2b2"

        # Send a GET request to the URL
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the page
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find the table element you want to scrape
            table = soup.find('table')

            # Initialize an empty list to store the scraped data
            data = []

            # Initialize a variable to store the current course category
            current_category = None

            # Find all rows (tr elements) in the table
            rows = table.find_all('tr')

            # Loop through each row and extract the data from the cells (td elements)
            for row in rows:
                # Check if this row represents a course category
                if row.find('th', colspan="3"):
                    current_category = row.get_text(strip=True)
                else:
                    # Find all cells (td elements) in the row
                    cells = row.find_all('td')
                    
                    # Check if the row has enough cells (at least 3)
                    if len(cells) >= 3:
                        # Extract text from each cell and store it in a list
                        row_data = [current_category] + [cell.get_text(strip=True) for cell in cells]

                        # Extract the course URL if available
                        course_link = cells[0].find('a', href=True)
                        if course_link:
                            course_url = "https://www.sp.edu.sg" + course_link['href']
                        else:
                            course_url = None

                        # Append the course URL to the row data
                        row_data.append(course_url)

                        # Append the row data to the main data list
                        data.append(row_data)

            # Remove empty rows (rows with no data)
            data = [row for row in data if row]

            # Add the name of the university before each row
            university_name = "Singapore Polytechnic"  # Change this to the actual name if needed
            data_with_university = [[university_name] + row for row in data]

            # Convert the data into a DataFrame
            df = pd.DataFrame(data_with_university, columns=["University", "Course Category", "Course Info", "2023 Planned Intake", "Range of Net 2023 JAE ELR2B2", "Course URL"])

            # Split the "Course Info" column into "Course Name" and "Course Code"
            df[['Course Name', 'Course Code']] = df['Course Info'].str.split("(", n=1, expand=True)

            # Remove everything starting from the ")" character in the "Course Code" column
            df['Course Code'] = df['Course Code'].str.split(')', n=1).str[0]

            # Drop the original "Course Info" column
            df.drop(columns=['Course Info'], inplace=True)
            new_df = df[['University', 'Course Category', 'Course Name', 'Course Code', '2023 Planned Intake', "Range of Net 2023 JAE ELR2B2", "Course URL"]]
            new_df = pd.DataFrame(new_df)
            url_course_desc_scrap(new_df)
            # Print the DataFrame
            #display(new_df)
            #new_df = new_df[new_df["University","Course Category","Course Name","Course Code","2023 Planned Intake","Range of Net 2023 JAE ELR2B2", "Course URL","Course Description","Career Prospect"]]
            new_df.to_csv("SP_scrap.csv",index = False)
            return new_df
        else:
            print("Failed to retrieve the webpage. Status code:", response.status_code)
    except Exception as e:
        print(e)
# Debug

try:
    sp= pd.read_csv('SP_scrap.csv') 
    display(sp.columns)
    print("SP Course data loaded from storage")
except: 
    print("SP Course data Scraped from internet")
    sp  = sp_scrap()
    display(sp)
# Out:
# Index(['University', 'Course Category', 'Course Name', 'Course Code',
#        '2023 Planned Intake', 'Range of Net 2023 JAE ELR2B2', 'Course URL',
#        'Course Description', 'Career Prospect'],
#       dtype='object')
# SP Course data loaded from storage

# %% [markdown]
# # TP

# %%
def extract_career_prospects(url):
    # Send a GET request to the web page
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page with lxml
        html_content = response.text
        dom = etree.HTML(html_content)

        # Use the specified XPath to select the element
        target_element = dom.xpath('/html/body/div[3]/div[1]/div/div[3]/div/div/div[2]/div/div[11]/div/div[3]/div')
        
        # Find all elements with class="full-tile-alignment"
        soup = BeautifulSoup(response.text, "html.parser")
        full_tile_elements = soup.find_all(class_="cmp-flip-tile__box")
        
        fulltext = []
        if target_element:
            # Extract the text from the selected element
            text = "".join(target_element[0].itertext())

            # Remove newlines from the text while preserving other spaces
            text = re.sub(r'\n', '', text)

            text = text.replace('\t', '')
            text = re.sub(r'\r\r', ': ', text)
            text = re.sub(r'\r', ',', text)
            # print(text)
            fulltext.append(text)
            return  ", ".join(fulltext)
            print("Success: Career")
        
        elif full_tile_elements:
            # Loop through each element and extract the text
            for element in full_tile_elements:
                text = element.get_text()
                # print(text)

                # Remove newlines from the text while preserving other spaces
                text = re.sub(r'\n\n', '', text)
                fulltext.append(text)
            print("Success: Career")
            return  ", ".join(fulltext)
        
        
        else:
            print("failed: Career")
            return "class not found"
            
    else:
        print("Failed: Career")
        return "Failed to retrieve the web page."
        
# Function to clean course URLs and extract descriptions
def url_course_desc_scrap(df):
    # Lists to store cleaned URLs and course descriptions
    #cleaned_urls = []
    course_descriptions = []
    career_prospects = []
    for index, row in df.iterrows():
        # Search for the course URL
        #code = row['Course Code']
        course_url = row['Course URL']
        #cleaned_urls.append(course_url)
        career_prospects.append(extract_career_prospects(course_url))
        webpage = requests.get(course_url)

            
        if webpage.status_code == 200:
            soup = BeautifulSoup(webpage.content, "html.parser")
            dom = etree.HTML(str(soup))
            # Define a regex pattern to match HTML tags
            html_tag_pattern = re.compile(r'<[^>]*>')
            # Use XPath to select the parent <p> element that contains the <strong> element
            paragraph_with_strong = dom.xpath('/html/body/div[3]/div[1]/div/div[3]/div/div/div[2]/div/div[3]/div/div')

            if paragraph_with_strong:
                # Extract the text from the selected <p> element and its children
                paragraph_text = etree.tostring(paragraph_with_strong[0], method='html').decode()
                cleaned_text = re.sub(html_tag_pattern, '', paragraph_text)
                course_descriptions.append(cleaned_text)
                print("Success: Description")
            else:
                print("Failed: Description")
                course_descriptions.append("Course description was not found")
        else :
            #cleaned_urls.append(course_url)
            print("Failed: Description")
            course_descriptions.append("Course URL not found")
    df["Course Description"] = course_descriptions
    df["Career Prospect"] = career_prospects
# Function to extract career prospects using XPath

def tp_scrap():
    # URL of the website to scrape
    url = "https://www.tp.edu.sg/admissions-and-finance/course-intake-aggregate-range.html"
    
    # Initialize empty lists to store data
    course_data = []
    
    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:

        # Parse the HTML content
        soup = BeautifulSoup(response.text, 'html.parser')
        current_category = None

        # Find all tables in the HTML
        tables = soup.find_all('table')

        # Loop through each table
        for table in tables:
            # Find the preceding <b> tag to determine the course category
            category_tag = table.find_previous('b')
            if category_tag:
                category = category_tag.get_text(strip=True)

                # Find all rows (tr elements) in the table
                rows = table.find_all('tr')

                # Loop through each row and extract the data from the cells (td elements)
                for row in rows[1:]:  # Skip the header row
                    cells = row.find_all('td')
                    # Extract text from each cell and store it in a list
                    course_name = cells[0].find('a').get_text(strip=True)
                    # print(course_name)
                    planned_intake = cells[1].get_text(strip=True)
                    elr2b2_range = cells[2].get_text(strip=True)
                    course_url = "https://www.tp.edu.sg" +cells[0].find('a')['href']
                    university_name = "Temasek Polytechnic"  # Change this to the actual name if needed

                    # Append the data to the course_data list
                    course_data.append([university_name, category, course_name, planned_intake, elr2b2_range, course_url])

        df = pd.DataFrame(course_data, columns=["University","Course Category", "Diploma", 
                                                "2023 Planned Intake", "Range of Net 2023 JAE ELR2B2", "Course URL"])
        # Split the "Diploma" column into "Course Name" and "Course Code"
        df[['Course Name', 'Course Code']] = df['Diploma'].str.split("(", n=1, expand=True)

        # Remove everything starting from the ")" character in the "Course Code" column
        df['Course Code'] = df['Course Code'].str.split(')', n=1).str[0]
        df.drop_duplicates(subset=['Diploma'])

        # Drop the original "Diploma" column
        df.drop(columns=['Diploma'], inplace=True)

        # Now select the desired columns and reorder them
        df = df[["University", "Course Category", "Course Name", "Course Code", "2023 Planned Intake", "Range of Net 2023 JAE ELR2B2", "Course URL"]]

        # Call the function to extract course descriptions and career prospects
        newdf = df.tail(41)
        url_course_desc_scrap(newdf)

        # Add the "Course Description" and "Career Prospect" columns
        newdf = newdf[["University", "Course Category", "Course Name", "Course Code", "2023 Planned Intake", "Range of Net 2023 JAE ELR2B2", "Course URL", "Course Description", "Career Prospect"]]

        # Save the DataFrame to a CSV file
        newdf.to_csv("TP_scrap.csv", index=False)
        return newdf
                         
        
# Debug
try:
    tp= pd.read_csv('TP_scrap.csv') 
    display(tp)
    print("TP Course data loaded from storage")
except: 
    print("TP Course data Scraped from internet")
    tp  = tp_scrap()
    display(tp)
# Out:
#              University                         Course Category  \
# 0   Temasek Polytechnic               School of Applied Science
# 1   Temasek Polytechnic               School of Applied Science
# 2   Temasek Polytechnic               School of Applied Science
# 3   Temasek Polytechnic               School of Applied Science
# 4   Temasek Polytechnic               School of Applied Science
# 5   Temasek Polytechnic               School of Applied Science
# 6   Temasek Polytechnic                      School of Business
# 7   Temasek Polytechnic                      School of Business
# 8   Temasek Polytechnic                      School of Business
# 9   Temasek Polytechnic                      School of Business
# 10  Temasek Polytechnic                      School of Business
# 11  Temasek Polytechnic                      School of Business
# 12  Temasek Polytechnic                      School of Business
# 13  Temasek Polytechnic                      School of Business
# 14  Temasek Polytechnic                      School of Business
# 15  Temasek Polytechnic                        School of Design
# 16  Temasek Polytechnic                        School of Design
# 17  Temasek Polytechnic                        School of Design
# 18  Temasek Polytechnic                        School of Design
# 19  Temasek Polytechnic                        School of Design
# 20  Temasek Polytechnic                        School of Design
# 21  Temasek Polytechnic                   School of Engineering
# 22  Temasek Polytechnic                   School of Engineering
# 23  Temasek Polytechnic                   School of Engineering
# 24  Temasek Polytechnic                   School of Engineering
# 25  Temasek Polytechnic                   School of Engineering
# 26  Temasek Polytechnic                   School of Engineering
# 27  Temasek Polytechnic                   School of Engineering
# 28  Temasek Polytechnic                   School of Engineering
# 29  Temasek Polytechnic                   School of Engineering
# 30  Temasek Polytechnic                   School of Engineering
# 31  Temasek Polytechnic                   School of Engineering
# 32  Temasek Polytechnic  School of Humanities & Social Sciences
# 33  Temasek Polytechnic  School of Humanities & Social Sciences
# 34  Temasek Polytechnic  School of Humanities & Social Sciences
# 35  Temasek Polytechnic              School of Informatics & IT
# 36  Temasek Polytechnic              School of Informatics & IT
# 37  Temasek Polytechnic              School of Informatics & IT
# 38  Temasek Polytechnic              School of Informatics & IT
# 39  Temasek Polytechnic              School of Informatics & IT
# 40  Temasek Polytechnic              School of Informatics & IT
#
#                                       Course Name Course Code  \
# 0                           Chemical Engineering          T33
# 1                       Common Science Programme          T70
# 2             Food, Nutrition & Culinary Science          T26
# 3                          Medical Biotechnology          T64
# 4                         Pharmaceutical Science          T25
# 5                          Veterinary Technology          T45
# 6                          Accountancy & Finance          T02
# 7                                       Business          T10
# 8                      Common Business Programme          T01
# 9              Communications & Media Management          T40
# 10                Culinary & Catering Management          T18
# 11              Hospitality & Tourism Management          T08
# 12                              Law & Management          T09
# 13               International Trade & Logistics          T07
# 14                                     Marketing          T67
# 15                Apparel Design & Merchandising          T20
# 16                       Common Design Programme          T71
# 17                          Communication Design          T59
# 18                     Digital Film & Television          T23
# 19                Interior Architecture & Design          T22
# 20                   Product Experience & Design          T35
# 21                         Aerospace Electronics          T50
# 22                         Aerospace Engineering          T51
# 23  Architectural Technology & Building Services          T29
# 24                           Aviation Management          T04
# 25                        Biomedical Engineering          T38
# 26        Business Process & Systems Engineering          T43
# 27                  Common Engineering Programme          T56
# 28                          Computer Engineering          T13
# 29                                   Electronics          T65
# 30                Integrated Facility Management          T28
# 31                                  Mechatronics          T66
# 32       Early Childhood Development & Education          T68
# 33                            Psychology Studies          T48
# 34                Social Sciences in Gerontology          T53
# 35               Applied Artificial Intelligence          T69
# 36                          Big Data & Analytics          T60
# 37                          Common ICT Programme          T63
# 38             Cybersecurity & Digital Forensics          T62
# 39            Immersive Media & Game Development          T58
# 40                        Information Technology          T30
#
#     2023 Planned Intake Range of Net 2023 JAE ELR2B2  \
# 0                   100                       5 - 14
# 1                   150                       7 - 12
# 2                    50                       8 - 10
# 3                    65                        3 - 9
# 4                    70                       5 - 10
# 5                    45                        5 - 9
# 6                   100                       5 - 11
# 7                   165                       5 - 13
# 8                   290                       6 - 15
# 9                    85                       6 - 13
# 10                   70                       3 - 19
# 11                  120                       6 - 17
# 12                  120                       5 - 12
# 13                   70                      11 - 16
# 14                   75                       8 - 15
# 15                   50                       8 - 12
# 16                  100                       7 - 15
# 17                   75                       3 - 15
# 18                   55                       3 - 11
# 19                   55                       4 - 11
# 20                   35                       5 - 16
# 21                   75                       7 - 17
# 22                  120                       6 - 15
# 23                  100                       5 - 23
# 24                   95                       7 - 15
# 25                   95                       8 - 14
# 26                  100                       5 - 16
# 27                  465                       8 - 21
# 28                  100                       4 - 13
# 29                   50                      10 - 15
# 30                   75                       4 - 19
# 31                   50                       9 - 16
# 32                  250                       3 - 19
# 33                   75                        3 - 8
# 34                   50                       9 - 14
# 35                   50                       4 - 12
# 36                   50                       5 - 11
# 37                  220                       5 - 16
# 38                  150                       4 - 11
# 39                   25                       8 - 13
# 40                  100                       5 - 15
#
#                                            Course URL  \
# 0   https://www.tp.edu.sg/schools-and-courses/stud...
# 1   https://www.tp.edu.sg/schools-and-courses/stud...
# 2   https://www.tp.edu.sg/schools-and-courses/stud...
# 3   https://www.tp.edu.sg/schools-and-courses/stud...
# 4   https://www.tp.edu.sg/schools-and-courses/stud...
# 5   https://www.tp.edu.sg/schools-and-courses/stud...
# 6   https://www.tp.edu.sg/schools-and-courses/stud...
# 7   https://www.tp.edu.sg/schools-and-courses/stud...
# 8   https://www.tp.edu.sg/schools-and-courses/stud...
# 9   https://www.tp.edu.sg/schools-and-courses/stud...
# 10  https://www.tp.edu.sg/schools-and-courses/stud...
# 11  https://www.tp.edu.sg/schools-and-courses/stud...
# 12  https://www.tp.edu.sg/schools-and-courses/stud...
# 13  https://www.tp.edu.sg/schools-and-courses/stud...
# 14  https://www.tp.edu.sg/schools-and-courses/stud...
# 15  https://www.tp.edu.sg/schools-and-courses/stud...
# 16  https://www.tp.edu.sg/schools-and-courses/stud...
# 17  https://www.tp.edu.sg/schools-and-courses/stud...
# 18  https://www.tp.edu.sg/schools-and-courses/stud...
# 19  https://www.tp.edu.sg/schools-and-courses/stud...
# 20  https://www.tp.edu.sg/schools-and-courses/stud...
# 21  https://www.tp.edu.sg/schools-and-courses/stud...
# 22  https://www.tp.edu.sg/schools-and-courses/stud...
# 23  https://www.tp.edu.sg/schools-and-courses/stud...
# 24  https://www.tp.edu.sg/schools-and-courses/stud...
# 25  https://www.tp.edu.sg/schools-and-courses/stud...
# 26  https://www.tp.edu.sg/schools-and-courses/stud...
# 27  https://www.tp.edu.sg/schools-and-courses/stud...
# 28  https://www.tp.edu.sg/schools-and-courses/stud...
# 29  https://www.tp.edu.sg/schools-and-courses/stud...
# 30  https://www.tp.edu.sg/schools-and-courses/stud...
# 31  https://www.tp.edu.sg/schools-and-courses/stud...
# 32  https://www.tp.edu.sg/schools-and-courses/stud...
# 33  https://www.tp.edu.sg/schools-and-courses/stud...
# 34  https://www.tp.edu.sg/schools-and-courses/stud...
# 35  https://www.tp.edu.sg/schools-and-courses/stud...
# 36  https://www.tp.edu.sg/schools-and-courses/stud...
# 37  https://www.tp.edu.sg/schools-and-courses/stud...
# 38  https://www.tp.edu.sg/schools-and-courses/stud...
# 39  https://www.tp.edu.sg/schools-and-courses/stud...
# 40  https://www.tp.edu.sg/schools-and-courses/stud...
#
#                                    Course Description  \
# 0   \nCourse Overview\nChemical engineers play a k...
# 1   \nCourse Overview\nAre you passionate about sc...
# 2   \nCourse Overview\nHave you ever wanted to exp...
# 3   \nCourse Overview\nHave you wondered about the...
# 4   \nCourse Overview\nMedicines affect our qualit...
# 5   \nCourse Overview\nTurn your love for animals ...
# 6   \nCourse Overview\nSeize the opportunity to th...
# 7   \nCourse Overview\nThrough this course, you wi...
# 8   \nCourse Overview\nOur one-year Common Busines...
# 9   \nCourse Overview\nThis course exposes you to ...
# 10  \nCourse Overview\nOur buzzing food and bevera...
# 11  \nCourse Overview\nGet ready to enter the exci...
# 12  \nCourse Overview\nThe only polytechnic law di...
# 13  \nCourse Overview\nAs part of the training, st...
# 14  \nCourse Overview\nHave you wondered what make...
# 15  \nCourse Overview\nDo you have an eye for styl...
# 16  \n\n\nCourse Overview\nDo you have a burning p...
# 17  \nCourse Overview\nAre you intrigued by how de...
# 18  \nCourse Overview\nAre you a film enthusiast? ...
# 19  \nCourse Overview\nDo you often admire the int...
# 20  \nCourse Overview\nEver wondered how global di...
# 21  \nCourse Overview\nIt takes an amazing enginee...
# 22  \nCourse Overview\nHave you always been fascin...
# 23  \nCourse Overview\nWe&#8217;ve all heard about...
# 24  \nCourse Overview\nWe've got one of the best a...
# 25  \nCourse Overview\nEver wondered how medical d...
# 26  \nCourse Overview\nHave an interest in both bu...
# 27  \nCourse Overview\nAre you an aspiring enginee...
# 28  \nCourse Overview\nDigitalisation is taking ov...
# 29  \nCourse Overview\nFrom the smartphones we own...
# 30  \nCourse Overview\nThe future of buildings is ...
# 31  \nCourse Overview\nWelcome to the era of advan...
# 32  \nCourse Overview\nIf nurturing the next gener...
# 33  \nCourse Overview\nEver find yourself in a &#8...
# 34  \nCourse Overview\nIn this rapidly changing wo...
# 35  \nCourse Overview\nDoes the exciting world of ...
# 36  \nCourse Overview\nThink Netflix, Amazon, Inst...
# 37  \nCourse Overview\nAre you excited and curious...
# 38  \nCourse Overview\nIn an increasingly digitise...
# 39  \nCourse Overview\nKeen to use augmented reali...
# 40  \nCourse Overview\nHow does my Grab app locate...
#
#                                       Career Prospect
# 0    Process Technicians\nExecutes safe and reliab...
# 1                                                 ...
# 2   Assistant Food Technologist\nPrepares equipmen...
# 3   Laboratory Assistant or Technical Support Offi...
# 4   Pharmacy Technician in Hospital and Retail Pha...
# 5   Veterinary Technician \nAssists veterinarians ...
# 6                                     class not found
# 7                                                 ...
# 8                                     class not found
# 9                                                 ...
# 10                                                ...
# 11                                                ...
# 12                                                ...
# 13                                                ...
# 14                                                ...
# 15                                                ...
# 16                                    class not found
# 17                                                ...
# 18                                    class not found
# 19                                                ...
# 20                                    class not found
# 21                                    class not found
# 22                                    class not found
# 23                                    class not found
# 24                                    class not found
# 25                                    class not found
# 26                                    class not found
# 27                                    class not found
# 28                                    class not found
# 29                                    class not found
# 30                                    class not found
# 31                                    class not found
# 32                                    class not found
# 33                                    class not found
# 34                                    class not found
# 35                                    class not found
# 36                                    class not found
# 37                                    class not found
# 38                                    class not found
# 39                                    class not found
# 40                                    class not found
# TP Course data loaded from storage

# %% [markdown]
# # Republic Polytechnic (RP)

# %%
# Sample DataFrame with course details and URLs
def search_course_url(row):
    query = f"Diploma in {row['Course Name']}({row['Course Code']}) {row['University']}"
    print(query)
    try:
        num_page = 1
        search_results = ddg(query, max_results=1)
        if search_results:
            #print(search_results)
            print(search_results[0]['href'])
            return search_results[0]['href']

    except Exception as e:
        print(e)
        return "No results found"


# Function to clean course URLs and extract descriptions
def url_course_desc_scrap(df):
    # Lists to store cleaned URLs, course descriptions, and career prospects
    cleaned_urls = []
    course_descriptions = []
    career_prospects = []

    for index, row in df.iterrows():
        # Search for the course URL
        course_url = search_course_url(row)

        if course_url == "No results found":
            cleaned_urls.append(course_url)
            course_descriptions.append("Course URL not found")
            career_prospects.append("Course URL not found")
        else:
            # Split the URL by '/' and keep only the first 7 components

            cleaned_urls.append(course_url)

            webpage = requests.get(course_url)

            if webpage.status_code == 200:
                soup = BeautifulSoup(webpage.content, "html.parser")
                dom = etree.HTML(str(soup))

                # Define a regex pattern to match HTML tags
                html_tag_pattern = re.compile(r'<[^>]*>')

                # Use XPath to select the parent <p> element that contains the <strong> element for course descriptions
                description = dom.xpath('/html/body/form/div[3]/div[2]/div/div/div[1]/div[3]/div/div/div[1]/p')
                if description:
                    # Extract the text from the selected <p> element and its children
                    paragraph_text = etree.tostring(description[0], method='html').decode()
                    cleaned_text = re.sub(html_tag_pattern, '', paragraph_text)
                    course_descriptions.append(cleaned_text)
                    print("Success: Description")
                else:
                    print("Failed: Description")
                    course_descriptions.append("Course description was not found")

                # Use XPath to select the parent <p> element that contains the career prospects
                prospect = dom.xpath("/html/body/form/div[3]/div[2]/div/div/div[1]/div[3]/div/div/div[4]/div")
                if prospect:
                    # Extract the text from the selected <p> element and its children
                    paragraph_text = etree.tostring(prospect[0], method='html').decode()
                    cleaned_text = re.sub(html_tag_pattern, '', paragraph_text)
                    career_prospects.append(cleaned_text)
                    print("Success: Career")
                else:
                    career_prospects.append("Career prospects were not found")
            else:
                print("Failed: Career")
                cleaned_urls.append(course_url)
                course_descriptions.append("Course URL not found")
                career_prospects.append("Career prospects were not found")

    # Add the cleaned URLs, course descriptions, and career prospects to the DataFrame
    df["Course URL"] = cleaned_urls
    df["Course Description"] = course_descriptions
    df["Career Prospect"] = career_prospects
    
def rp_scrap():
    try:
        # URL of the website to scrape
        url = "https://www.rp.edu.sg/admissions/course-intake-numbers"

        # University name
        university_name = "Republic Polytechnic"

        # Send a GET request to the URL
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the page
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all tables on the page
            tables = soup.find_all('table')

            # Initialize an empty list to store data from all tables
            all_data = []

            # Loop through each table
            for table in tables:
                # Initialize an empty list to store data from the current table
                data = []

                # Find all rows (tr elements) in the table
                rows = table.find_all('tr')

                # Loop through each row and extract the data from the cells (td elements)
                for row in rows:
                    # Find all cells (td elements) in the row
                    cells = row.find_all('td')

                    # Extract text from each cell and store it in a list
                    row_data = [cell.get_text(strip=True) for cell in cells]

                    # Append the row data to the current table's data list
                    data.append(row_data)

                # Remove empty rows (rows with no data)
                data = [row for row in data if row]



                # Extract the course category from the table (assuming it's in the h3 header)
                course_category = table.find_previous('h3').text.strip()

                # Add the course category to each row
                data_with_category = [[course_category] + row for row in data]
                
                # Add the name of the university before each row
                data_with_university = [[university_name] + row for row in data_with_category]
                # Convert the data into a DataFrame for the current table
                df = pd.DataFrame(data_with_university, columns=['University','Course Category',  "Course Name", "Course Code", "Aggregate Type", "2023 Planned Intake", "Range of Net 2023 JAE ELR2B2"])
                
                # Drop the original "Course Info" column
                df.drop(columns=['Aggregate Type'], inplace=True)

                # Drop the original "Aggregate Type" column
                #df.drop(columns=['Category'], inplace=True)

                # Append the current table's data to the list of all data
                all_data.append(df)

            # Combine data from all tables into a single DataFrame
            combined_df = pd.concat(all_data, ignore_index=True)
            #combined_df = combined_df [combined_df["University","Course Category","Course Name","Course Code","2023 Planned Intake","Range of Net 2023 JAE ELR2B2"]]

            
            # Print the DataFrame
            url_course_desc_scrap(combined_df)
            #display(combined_df)
            combined_df.to_csv("RP_scrap.csv",index = False)
            return combined_df

        else:
            print("Failed to retrieve the webpage. Status code:", response.status_code)
    except Exception as e:
        print(e)
# Debug 
try:
    rp= pd.read_csv('RP_scrap.csv') 
    display(rp)
    print("RP Course data loaded from storage")
except: 
    print("RP Course data Scraped from internet")
    rp  = rp_scrap()
    display(rp)
# Out:
#               University                         Course Category  \
# 0   Republic Polytechnic               School of Applied Science
# 1   Republic Polytechnic               School of Applied Science
# 2   Republic Polytechnic               School of Applied Science
# 3   Republic Polytechnic               School of Applied Science
# 4   Republic Polytechnic               School of Applied Science
# 5   Republic Polytechnic               School of Applied Science
# 6   Republic Polytechnic                   School of Engineering
# 7   Republic Polytechnic                   School of Engineering
# 8   Republic Polytechnic                   School of Engineering
# 9   Republic Polytechnic                   School of Engineering
# 10  Republic Polytechnic                   School of Engineering
# 11  Republic Polytechnic                   School of Engineering
# 12  Republic Polytechnic                   School of Engineering
# 13  Republic Polytechnic                   School of Engineering
# 14  Republic Polytechnic                   School of Engineering
# 15  Republic Polytechnic                   School of Hospitality
# 16  Republic Polytechnic                   School of Hospitality
# 17  Republic Polytechnic                   School of Hospitality
# 18  Republic Polytechnic                   School of Hospitality
# 19  Republic Polytechnic                   School of Hospitality
# 20  Republic Polytechnic                      School of Infocomm
# 21  Republic Polytechnic                      School of Infocomm
# 22  Republic Polytechnic                      School of Infocomm
# 23  Republic Polytechnic                      School of Infocomm
# 24  Republic Polytechnic                      School of Infocomm
# 25  Republic Polytechnic                      School of Infocomm
# 26  Republic Polytechnic    School of Sports, Health and Leisure
# 27  Republic Polytechnic    School of Sports, Health and Leisure
# 28  Republic Polytechnic    School of Sports, Health and Leisure
# 29  Republic Polytechnic    School of Sports, Health and Leisure
# 30  Republic Polytechnic    School of Sports, Health and Leisure
# 31  Republic Polytechnic    School of Sports, Health and Leisure
# 32  Republic Polytechnic  School of Management and Communication
# 33  Republic Polytechnic  School of Management and Communication
# 34  Republic Polytechnic  School of Management and Communication
# 35  Republic Polytechnic  School of Management and Communication
# 36  Republic Polytechnic  School of Management and Communication
# 37  Republic Polytechnic       School of Technology for the Arts
# 38  Republic Polytechnic       School of Technology for the Arts
# 39  Republic Polytechnic       School of Technology for the Arts
# 40  Republic Polytechnic       School of Technology for the Arts
# 41  Republic Polytechnic       School of Technology for the Arts
# 42  Republic Polytechnic       School of Technology for the Arts
#
#                                      Course Name Course Code  \
# 0                             Biomedical Science         R14
# 1                                  Biotechnology         R16
# 2                              Applied Chemistry         R17
# 3                         Pharmaceutical Science         R22
# 4                       Common Science Programme         R59
# 5                 Environmental & Marine Science         R62
# 6             Industrial & Operations Management         R11
# 7                        Supply Chain Management         R21
# 8                            Aviation Management         R39
# 9                          Aerospace Engineering         R40
# 10                  Common Engineering Programme         R42
# 11           Electrical & Electronic Engineering         R50
# 12              Engineering Systems & Management         R54
# 13              Engineering Design with Business         R56
# 14                 Sustainable Built Environment         R61
# 15                  Integrated Events Management         R28
# 16  Customer Experience Management with Business         R34
# 17                Hotel & Hospitality Management         R37
# 18              Restaurant & Culinary Operations         R46
# 19            Tourism Management with Technology         R64
# 20                        Information Technology         R12
# 21                  Business Information Systems         R13
# 22                          Financial Technology         R18
# 23                  Digital Design & Development         R47
# 24                  Infocomm Security Management         R55
# 25                          Common ICT Programme         R58
# 26                      Sport & Exercise Science         R26
# 27                  Outdoor & Adventure Learning         R33
# 28                 Health Management & Promotion         R43
# 29                    Health Services Management         R45
# 30                                Sport Coaching         R49
# 31            Common Sports and Health Programme         R63
# 32                            Mass Communication         R32
# 33                 Consumer Behaviour & Research         R48
# 34     Human Resource Management with Psychology         R52
# 35                     Common Business Programme         R57
# 36                                      Business         R60
# 37                     Media Production & Design         R19
# 38                                    Sonic Arts         R24
# 39                     Arts & Theatre Management         R25
# 40               Design for Games & Gamification         R35
# 41                    Design for User Experience         R36
# 42       Common Arts, Design and Media Programme         R65
#
#     2023 Planned Intake Range of Net 2023 JAE ELR2B2  \
# 0                    98                      7 to 12
# 1                    93                      8 to 19
# 2                    51                     12 to 18
# 3                   152                      8 to 19
# 4                   194                     12 to 18
# 5                    64                      8 to 15
# 6                    81                     14 to 26
# 7                    81                     13 to 26
# 8                    85                     15 to 25
# 9                    96                     12 to 26
# 10                  294                    13 to 26*
# 11                  125                    18 to 26*
# 12                   64                    15 to 21*
# 13                   64                    16 to 26*
# 14                   48                    16 to 26*
# 15                   97                    15 to 26*
# 16                   76                    15 to 22*
# 17                   96                    13 to 26*
# 18                   56                    14 to 26*
# 19                   57                    17 to 25*
# 20                  141                     15 to 26
# 21                  125                     15 to 26
# 22                  122                     16 to 26
# 23                   90                     15 to 26
# 24                   88                     10 to 25
# 25                  245                     13 to 26
# 26                  103                      6 to 14
# 27                   44                    11 to 25*
# 28                   63                    14 to 26*
# 29                   73                    16 to 26*
# 30                   45                     13 to 18
# 31                  136                    12 to 26*
# 32                  117                      9 to 16
# 33                   63                     14 to 18
# 34                   68                      8 to 16
# 35                  270                     8 to 26*
# 36                  121                      9 to 20
# 37                   86                     13 to 18
# 38                   51                     11 to 18
# 39                   51                     13 to 19
# 40                   48                     12 to 17
# 41                   53                     15 to 20
# 42                  125                     13 to 20
#
#                                            Course URL  \
# 0   https://www.rp.edu.sg/SAS/full-time-diplomas/D...
# 1   https://www.rp.edu.sg/SAS/full-time-diplomas/D...
# 2   https://www.rp.edu.sg/SAS/full-time-diplomas/D...
# 3   https://www.rp.edu.sg/SAS/full-time-diplomas/D...
# 4   https://www.rp.edu.sg/SAS/full-time-diplomas/D...
# 5   https://www.rp.edu.sg/SAS/full-time-diplomas/D...
# 6   https://www.rp.edu.sg/SEG/full-time-diplomas/D...
# 7   https://www.rp.edu.sg/SEG/full-time-diplomas/D...
# 8   https://www.rp.edu.sg/SEG/full-time-diplomas/D...
# 9   https://www.rp.edu.sg/SEG/full-time-diplomas/D...
# 10  https://www.rp.edu.sg/SEG/full-time-diplomas/D...
# 11       https://www.rp.edu.sg/seg/full-time-diplomas
# 12       https://www.rp.edu.sg/seg/full-time-diplomas
# 13  https://www.rp.edu.sg/SEG/full-time-diplomas/D...
# 14  https://www.rp.edu.sg/SEG/full-time-diplomas/D...
# 15  https://www.rp.edu.sg/Soh/full-time-diplomas/D...
# 16       https://www.rp.edu.sg/soh/full-time-diplomas
# 17  https://www.rp.edu.sg/Soh/full-time-diplomas/D...
# 18  https://www.rp.edu.sg/soh/full-time-diplomas/D...
# 19  https://www.rp.edu.sg/soh/full-time-diplomas/d...
# 20       https://www.rp.edu.sg/soi/full-time-diplomas
# 21  https://www.rp.edu.sg/soi/full-time-diplomas/d...
# 22  https://www.rp.edu.sg/SOI/full-time-diplomas/D...
# 23       https://www.rp.edu.sg/soi/full-time-diplomas
# 24  https://www.rp.edu.sg/SOI/full-time-diplomas/D...
# 25  https://www.rp.edu.sg/SOI/full-time-diplomas/D...
# 26  https://www.rp.edu.sg/Shl/full-time-diplomas/D...
# 27  https://www.rp.edu.sg/Shl/full-time-diplomas/D...
# 28  https://www.rp.edu.sg/Shl/full-time-diplomas/D...
# 29  https://www.rp.edu.sg/Shl/full-time-diplomas/D...
# 30  https://www.rp.edu.sg/Shl/full-time-diplomas/D...
# 31  https://www.rp.edu.sg/shl/full-time-diplomas/d...
# 32       https://www.rp.edu.sg/smc/full-time-diplomas
# 33       https://www.rp.edu.sg/smc/full-time-diplomas
# 34  https://www.rp.edu.sg/SMC/full-time-diplomas/D...
# 35       https://www.rp.edu.sg/smc/full-time-diplomas
# 36  https://www.rp.edu.sg/smc/full-time-diplomas/d...
# 37  https://www.rp.edu.sg/STA/full-time-diplomas/D...
# 38  https://www.rp.edu.sg/STA/full-time-diplomas/D...
# 39  https://www.rp.edu.sg/STA/full-time-diplomas/D...
# 40  https://www.rp.edu.sg/sta/full-time-diplomas/D...
# 41  https://www.rp.edu.sg/STA/full-time-diplomas/D...
# 42  https://www.rp.edu.sg/sta/full-time-diplomas/d...
#
#                                    Course Description  \
# 0   Turn your fascination with the human body's re...
# 1   Understand new breakthroughs in science and ta...
# 2   From pharmaceutical drugs to skincare products...
# 3   Play a pivotal role in driving advances in mod...
# 4   Intrigued by the science behind everything?&#1...
# 5   Be at the forefront of protecting the environm...
# 6   Craft operational strategies that can transfor...
# 7   The Diploma in Supply Chain\nManagement (DSCM)...
# 8   \nAchieve your aspirations in the aviation ind...
# 9   Your runway to becoming a licensed Aircraft En...
# 10  \nStay flexible and keep your options open as ...
# 11                   Course description was not found
# 12                   Course description was not found
# 13  Be the visionary engineer, product designer an...
# 14  Flourish in the built environment industry wit...
# 15  Organise events that connect, inspire and buil...
# 16                   Course description was not found
# 17  Immerse yourself in the world of hospitality t...
# 18  Explore the world of gastronomy and unleash yo...
# 19  Rediscover the tourism industry through digita...
# 20                   Course description was not found
# 21  Harness your IT skills to contribute to the bu...
# 22  Learn what it takes to be a FinTech profession...
# 23                   Course description was not found
# 24  Be at the frontline of cyber security.&#160;\n...
# 25  ICT is a constantly evolving industry with a h...
# 26  Drive the science that supports the Sports Ind...
# 27  Nature or Nurture? We nurture people through n...
# 28  Be the Health Coach who inspires change.\n\nYo...
# 29  A reputation as a smooth operator is a good th...
# 30  Be the coach behind a successful sportsman.\n\...
# 31  Always had a passion in sports and health, but...
# 32                   Course description was not found
# 33                   Course description was not found
# 34  Turn your passion for people to take on a stra...
# 35                   Course description was not found
# 36  Diploma in Business (DBIZ) is a transformative...
# 37  Dynamic and inventive storytelling starts here...
# 38  Harness technical skills together with your cr...
# 39  Transform your creative vision with technical ...
# 40  Level up in game design and shape the world!\n...
# 41  Unleash infinite opportunities in the User Exp...
# 42  Unveil your passion and showcase your creative...
#
#                                       Career Prospect
# 0   \n\nOption 1: Biomedical Research Track\n\nA24...
# 1   \n\nOption 1: Biologics Track\n\nA103 Anatomy ...
# 2   \n\nOption 1: Materials Science Track\n\nA217 ...
# 3   \n\nOption 1: Industrial Pharmacy Track\n\nA36...
# 4   \nFurther Studies\nUpon completion of the Comm...
# 5   \n\nOption 1: Environmental Management and Tec...
# 6                     Career prospects were not found
# 7                     Career prospects were not found
# 8                     Career prospects were not found
# 9                     Career prospects were not found
# 10                    Career prospects were not found
# 11                    Career prospects were not found
# 12                    Career prospects were not found
# 13                    Career prospects were not found
# 14                    Career prospects were not found
# 15                    Career prospects were not found
# 16                    Career prospects were not found
# 17                    Career prospects were not found
# 18                    Career prospects were not found
# 19                    Career prospects were not found
# 20                    Career prospects were not found
# 21  \nCareer Opportunities\nYou will gain versatil...
# 22                    Career prospects were not found
# 23                    Career prospects were not found
# 24                    Career prospects were not found
# 25  \nFurther Studies\nUpon completion of the Comm...
# 26  \nCareer Opportunities\nAim high after you gra...
# 27                    Career prospects were not found
# 28                    Career prospects were not found
# 29                    Career prospects were not found
# 30                    Career prospects were not found
# 31  \nCareer Opportunities\nAim high after you gra...
# 32                    Career prospects were not found
# 33                    Career prospects were not found
# 34                    Career prospects were not found
# 35                    Career prospects were not found
# 36                    Career prospects were not found
# 37                    Career prospects were not found
# 38                    Career prospects were not found
# 39                    Career prospects were not found
# 40                    Career prospects were not found
# 41                    Career prospects were not found
# 42  \nFurther Studies\nUpon completion of the Comm...
# RP Course data loaded from storage

# %% [markdown]
# # Ngee Ann Polytechnic (NP)

# %%
def search_course_url(row):
    query = f"Diploma in {row['Course Name']}({row['Course Code']}) {row['University']}"
    #print(query)
    try:
        num_page = 1
        search_results = ddg(query, max_results=1)
        if search_results:
            #print(search_results)
            print(search_results[0]['href'])
            return search_results[0]['href']

    except Exception as e:
        print(e)
        return "No results found"


# Function to clean course URLs and extract descriptions
def url_course_desc_scrap(df):
    # Lists to store cleaned URLs, course descriptions, and career prospects
    cleaned_urls = []
    course_descriptions = []
    career_prospects = []

    for index, row in df.iterrows():
        # Search for the course URL
        course_url = search_course_url(row)

        if course_url == "No results found":
            print("Failed:: ALL")
            cleaned_urls.append(course_url)
            course_descriptions.append("Course URL not found")
            career_prospects.append("Course URL not found")
        else:
            # Split the URL by '/' and keep only the first 7 components

            cleaned_urls.append(course_url)

            webpage = requests.get(course_url)

            if webpage.status_code == 200:
                soup = BeautifulSoup(webpage.content, "html.parser")
                dom = etree.HTML(str(soup))

                # Define a regex pattern to match HTML tags
                html_tag_pattern = re.compile(r'<[^>]*>')

                # Use XPath to select the parent <p> element that contains the <strong> element for course descriptions
                description = dom.xpath('/html/body/main/section[2]/div/div[2]/div[2]/p[1]')
                if description:
                    # Extract the text from the selected <p> element and its children
                    paragraph_text = etree.tostring(description[0], method='html').decode()
                    cleaned_text = re.sub(html_tag_pattern, '', paragraph_text)
                    course_descriptions.append(cleaned_text)
                    print("Success: Description")
                else:
                    course_descriptions.append("Course description was not found")
                    print("Failed: Description")

                # Use XPath to select the parent <p> element that contains the career prospects
                prospect = dom.xpath("/html/body/main/section[2]/div/div[2]/div[2]/ul[2]")
                if prospect:
                    # Extract the text from the selected <p> element and its children
                    paragraph_text = etree.tostring(prospect[0], method='html').decode()
                    cleaned_text = re.sub(html_tag_pattern, '', paragraph_text)
                    career_prospects.append(cleaned_text)
                    print("Success: Prospect")
                    
                else:
                    print("Failed: Prospect")
                    career_prospects.append("Career prospects were not found")
            else:
                course_descriptions.append("Course URL not found")
                career_prospects.append("Career prospects were not found")

    # Add the cleaned URLs, course descriptions, and career prospects to the DataFrame
    df["Course URL"] = cleaned_urls
    df["Course Description"] = course_descriptions
    df["Career Prospect"] = career_prospects
def np_scrap():
    try:
        # URL of the website to scrape
        url = "https://www.np.edu.sg/admissions-enrolment/guide-for-prospective-students/elr2b2"

        # Send a GET request to the URL
        response = requests.get(url)

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            # Parse the HTML content of the page
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find the table element you want to scrape
            table = soup.find('table')

            # Initialize an empty list to store the scraped data
            data = []
            
            # Initialize a variable to store the current course category
            current_category = None

            # Find all rows (tr elements) in the table
            rows = table.find_all('tr')

            # Loop through each row and extract the data from the cells (td elements)
            for row in rows:
                # Check if this row represents a course category
                if row.find('th', colspan="4"):
                    current_category = row.get_text(strip=True)
                else:
                    # Find all cells (td elements) in the row
                    cells = row.find_all('td')
                    
                    # Check if the row has enough cells (at least 3)
                    if len(cells) >= 3:
                        # Extract text from each cell and store it in a list
                        row_data = [current_category] + [cell.get_text(strip=True) for cell in cells]

                        # Extract the course URL if available
#                         course_link = cells[0].find('a', href=True)
#                         if course_link:
#                             course_url = "https://www.np.edu.sg" + course_link['href']
#                         else:
#                             course_url = None

#                         # Append the course URL to the row data
#                         row_data.append(course_url)

                        # Append the row data to the main data list
                        data.append(row_data)

            # Remove empty rows (rows with no data)
            data = [row for row in data if row]

            # Add the name of the university before each row
            university_name = "Ngee Ann Polytechnic"  # Change this to the actual name if needed
            data_with_university = [[university_name] + row for row in data]

             # Convert the data into a DataFrame for the current table
            df = pd.DataFrame(data_with_university, columns=["University","Course Category","Course", "Aggregate Type", "Range of Net 2023 JAE ELR2B2", "2023 Planned Intake"])

            # Step 1: Remove "New!" from the "Course" column
            df["Course"] = df["Course"].str.replace("New!", "").str.strip()

            # Step 2: Extract the last three characters and put them in "Course Code"
            df["Course Code"] = df["Course"].str[-3:]

            # Step 3: Put the remaining characters in "Course Name"
            df["Course Name"] = df["Course"].str[:-3].str.strip()
            df = df.drop(columns=['Course','Aggregate Type'])
            new_df = df[['University',"Course Category", 'Course Name', 'Course Code', '2023 Planned Intake', "Range of Net 2023 JAE ELR2B2"]]

            url_course_desc_scrap(new_df)
            
            # Print the DataFrame
            #display(new_df)
            new_df.to_csv("NP_scrap.csv",index = False)
            return new_df

        else:
            print("Failed to retrieve the webpage. Status code:", response.status_code)
    except Exception as e:
         print(e)
# Debug 
try:
    np= pd.read_csv('NP_scrap.csv') 
    display(np)
    print("NP Course data loaded from storage")
except: 
    print("NP Course data Scraped from internet")
    np  = np_scrap()
    display(np)
# Out:
#               University                     Course Category  \
# 0   Ngee Ann Polytechnic                    Applied Sciences
# 1   Ngee Ann Polytechnic                    Applied Sciences
# 2   Ngee Ann Polytechnic                    Applied Sciences
# 3   Ngee Ann Polytechnic                    Applied Sciences
# 4   Ngee Ann Polytechnic                    Applied Sciences
# 5   Ngee Ann Polytechnic                    Applied Sciences
# 6   Ngee Ann Polytechnic                   Built Environment
# 7   Ngee Ann Polytechnic               Business & Management
# 8   Ngee Ann Polytechnic               Business & Management
# 9   Ngee Ann Polytechnic               Business & Management
# 10  Ngee Ann Polytechnic               Business & Management
# 11  Ngee Ann Polytechnic               Business & Management
# 12  Ngee Ann Polytechnic               Business & Management
# 13  Ngee Ann Polytechnic               Business & Management
# 14  Ngee Ann Polytechnic               Business & Management
# 15  Ngee Ann Polytechnic                         Engineering
# 16  Ngee Ann Polytechnic                         Engineering
# 17  Ngee Ann Polytechnic                         Engineering
# 18  Ngee Ann Polytechnic                         Engineering
# 19  Ngee Ann Polytechnic                         Engineering
# 20  Ngee Ann Polytechnic                         Engineering
# 21  Ngee Ann Polytechnic                         Engineering
# 22  Ngee Ann Polytechnic                         Engineering
# 23  Ngee Ann Polytechnic                     Health Sciences
# 24  Ngee Ann Polytechnic                     Health Sciences
# 25  Ngee Ann Polytechnic                          Humanities
# 26  Ngee Ann Polytechnic                          Humanities
# 27  Ngee Ann Polytechnic                          Humanities
# 28  Ngee Ann Polytechnic                          Humanities
# 29  Ngee Ann Polytechnic  Information & Digital Technologies
# 30  Ngee Ann Polytechnic  Information & Digital Technologies
# 31  Ngee Ann Polytechnic  Information & Digital Technologies
# 32  Ngee Ann Polytechnic  Information & Digital Technologies
# 33  Ngee Ann Polytechnic  Information & Digital Technologies
# 34  Ngee Ann Polytechnic                    Maritime Studies
# 35  Ngee Ann Polytechnic                      Media & Design
# 36  Ngee Ann Polytechnic                      Media & Design
# 37  Ngee Ann Polytechnic                      Media & Design
# 38  Ngee Ann Polytechnic                      Media & Design
# 39  Ngee Ann Polytechnic                      Media & Design
# 40  Ngee Ann Polytechnic                      Media & Design
#
#                                 Course Name Course Code  2023 Planned Intake  \
# 0                        Biomedical Science         N59                   60
# 1       Chemical & Biomolecular Engineering         N56                   75
# 2                  Common Science Programme         N15                   50
# 3          Environmental & Water Technology         N74                   45
# 4           Landscape Design & Horticulture         N57                   40
# 5                    Pharmaceutical Science         N73                   50
# 6     Hotel & Leisure Facilities Management         N40                   95
# 7                               Accountancy         N51                  135
# 8                  Arts Business Management         N91                   40
# 9                         Banking & Finance         N53                   75
# 10                         Business Studies         N45                  150
# 11                Common Business Programme         N97                  220
# 12           International Trade & Business         N85                   75
# 13                     Real Estate Business         N48                   75
# 14              Tourism & Resort Management         N72                   50
# 15                    Aerospace Engineering         N65                  125
# 16                Mechatronics & Robotics *         N50                   75
# 17                   Biomedical Engineering         N60                   50
# 18             Common Engineering Programme         N71                  325
# 19                   Electrical Engineering         N43                   75
# 20        Electronic & Computer Engineering         N44                  125
# 21                      Engineering Science         N93                   40
# 22                   Mechanical Engineering         N41                  125
# 23                                  Nursing         N69                  600
# 24                                Optometry         N83                   45
# 25                          Chinese Studies         N70                   50
# 26                    Community Development         N11                   85
# 27  Early Childhood Development & Education         N96                  450
# 28       Tamil Studies with Early Education         N95                   30
# 29                     Common ICT Programme         N98                  125
# 30        Cybersecurity & Digital Forensics         N94                   75
# 31                             Data Science         N81                   50
# 32                          Immersive Media         N55                   50
# 33                   Information Technology         N54                  125
# 34             Marine & Offshore Technology         N42                   40
# 35            Chinese Media & Communication         N88                   40
# 36                   Common Media Programme         N14                   70
# 37                                   Design         N12                   75
# 38                      Film, Sound & Video         N82                   40
# 39                       Mass Communication         N67                   75
# 40                    Media Post-Production         N13                   40
#
#    Range of Net 2023 JAE ELR2B2  \
# 0                        3 to 7
# 1                       8 to 12
# 2                        5 to 9
# 3                       6 to 15
# 4                       4 to 16
# 5                        3 to 9
# 6                       7 to 17
# 7                       4 to 12
# 8                       5 to 12
# 9                       5 to 10
# 10                       3 to 8
# 11                      3 to 12
# 12                      8 to 13
# 13                      8 to 14
# 14                     10 to 15
# 15                      9 to 18
# 16                      6 to 26
# 17                      6 to 11
# 18                      7 to 24
# 19                     12 to 24
# 20                      5 to 16
# 21                      6 to 11
# 22                      4 to 26
# 23                    6 to 28 *
# 24                      6 to 13
# 25                      5 to 12
# 26                      5 to 13
# 27                      5 to 23
# 28                     15 to 20
# 29                      3 to 12
# 30                      3 to 10
# 31                      4 to 10
# 32                      5 to 14
# 33                      5 to 14
# 34                     14 to 25
# 35                      4 to 13
# 36                      7 to 12
# 37                      4 to 15
# 38                      3 to 11
# 39                       3 to 8
# 40                      3 to 13
#
#                                            Course URL  \
# 0   https://www.np.edu.sg/schools-courses/academic...
# 1   https://www.np.edu.sg/schools-courses/academic...
# 2   https://www.np.edu.sg/schools-courses/academic...
# 3   https://www.np.edu.sg/schools-courses/academic...
# 4   https://www.np.edu.sg/schools-courses/academic...
# 5   https://www.np.edu.sg/schools-courses/academic...
# 6   https://www.np.edu.sg/schools-courses/academic...
# 7   https://www.np.edu.sg/schools-courses/academic...
# 8   https://www.np.edu.sg/schools-courses/academic...
# 9   https://www.np.edu.sg/schools-courses/academic...
# 10  https://www.np.edu.sg/schools-courses/academic...
# 11  https://www.np.edu.sg/schools-courses/academic...
# 12  https://www.np.edu.sg/schools-courses/academic...
# 13  https://www.np.edu.sg/schools-courses/academic...
# 14  https://www.np.edu.sg/schools-courses/academic...
# 15  https://www.np.edu.sg/schools-courses/academic...
# 16  https://www.np.edu.sg/schools-courses/academic...
# 17  https://www.np.edu.sg/schools-courses/academic...
# 18  https://www.np.edu.sg/schools-courses/academic...
# 19  https://www.np.edu.sg/schools-courses/academic...
# 20  https://www.np.edu.sg/schools-courses/academic...
# 21  https://www.np.edu.sg/schools-courses/academic...
# 22  https://www.np.edu.sg/schools-courses/academic...
# 23  https://www.np.edu.sg/schools-courses/academic...
# 24  https://www.np.edu.sg/schools-courses/academic...
# 25  https://www.np.edu.sg/schools-courses/academic...
# 26  https://www.np.edu.sg/schools-courses/academic...
# 27  https://www.np.edu.sg/schools-courses/academic...
# 28  https://www.np.edu.sg/schools-courses/academic...
# 29  https://www.np.edu.sg/schools-courses/academic...
# 30  https://www.np.edu.sg/schools-courses/academic...
# 31  https://www.np.edu.sg/schools-courses/academic...
# 32  https://www.np.edu.sg/schools-courses/academic...
# 33  https://www.np.edu.sg/schools-courses/academic...
# 34  https://www.np.edu.sg/schools-courses/academic...
# 35  https://www.np.edu.sg/schools-courses/academic...
# 36  https://www.np.edu.sg/schools-courses/academic...
# 37  https://www.np.edu.sg/schools-courses/academic...
# 38  https://www.np.edu.sg/schools-courses/academic...
# 39  https://www.np.edu.sg/schools-courses/academic...
# 40  https://www.np.edu.sg/schools-courses/academic...
#
#                                    Course Description  \
# 0   Fascinated by the structure of living organism...
# 1   A broad-based course that integrates biologica...
# 2   Want to make a difference in the world of scie...
# 3   With life in Singapore set to be much greener ...
# 4   Want to be the creative drive behind Singapore...
# 5   Discover what it is like to work at the forefr...
# 6   Smart technology is transforming the hotel and...
# 7   Beyond bookkeeping and budgeting, accounting w...
# 8   If you love the idea of planning arts events, ...
# 9   Technology, innovation and sustainability are ...
# 10  Be prepared for today&#8217;s dynamic business...
# 11  Interested in pursuing business but unsure of ...
# 12  Ever wondered how global e-commerce platforms ...
# 13  If you have an interest in both real estate an...
# 14  With international tourism set to return to pr...
# 15  Growing up, were you fascinated with how a hea...
# 16  Robots are changing our daily lives &#8211; im...
# 17  Fascinated by how engineering and biology can ...
# 18  If you are keen on engineering, but unsure abo...
# 19  As Singapore embarks on the Green Plan 2030, o...
# 20  Who can live without electronics and computers...
# 21  You&#8217;re passionate about engineering appl...
# 22  Mechanical engineering touches virtually every...
# 23  The Diploma in Nursing (NSG) is a comprehensiv...
# 24  As one of the five senses, sight is vital to p...
# 25  *Students who select the Education specialisat...
# 26  Passionate about making an impact in the commu...
# 27      *subject to prevailing terms and conditions\n
# 28  Has it always been your dream to be an early c...
# 29  Fascinated by the world of infocomm technology...
# 30  You are a digital warrior raring to join the f...
# 31  With each click, like and share, data is being...
# 32  Technology is advancing more rapidly than ever...
# 33  Be a part of a vibrant IT start-up, develop es...
# 34  Fascinated by ships and how they work? Set sai...
# 35  Ever dreamt of entering the booming Chinese me...
# 36  Want to try out different media disciplines be...
# 37  Designers play a key role in developing soluti...
# 38  How many of us spend hours engrossed in the st...
# 39  A compelling narrative has the power to impact...
# 40  Want to put together larger-than-life interact...
#
#                                       Career Prospect
# 0   Australian National UniversityMurdoch Universi...
# 1   The University of AdelaideThe University of Me...
# 2                     Career prospects were not found
# 3   Murdoch UniversityThe University of AdelaideTh...
# 4   Australian National UniversityMonash Universit...
# 5   Monash UniversityQueensland University of Tech...
# 6   National University of Singapore&#160;Bachelor...
# 7   Business AdvisorBusiness Analyst&#160;Environm...
# 8   Edith Cowan University&#160;\n        Bachelor...
# 9                     Career prospects were not found
# 10  Business ConsultingCorporate CommunicationsEve...
# 11                    Career prospects were not found
# 12  Business Development Executive&#160;Internatio...
# 13  National University of SingaporeBachelor of Sc...
# 14                    Career prospects were not found
# 15  Planning ExecutivePlanning SupervisorSenior Te...
# 16  Nanyang Technological UniversityNational Unive...
# 17  University of New South WalesBachelor of Engin...
# 18                    Career prospects were not found
# 19  Assistant Engineer inPowerProject DevelopmentC...
# 20  National University of SingaporeNanyang Techno...
# 21  &gt;10 ES graduates topped their cohorts to cl...
# 22  Nanyang Technological UniversityNational Unive...
# 23                    Career prospects were not found
# 24  Queensland University of TechnologyUniversity ...
# 25  Nanyang Technological UniversityNational Unive...
# 26  Nanyang Technological UniversityNational Unive...
# 27  Child Support and Family ServicesEarly Interve...
# 28  National Institute of Education / Nanyang Tech...
# 29                    Career prospects were not found
# 30  Nanyang Technological UniversityNational Unive...
# 31  Nanyang Technological UniversityNational Unive...
# 32  DigiPen Institute of Technology&#160;Nanyang T...
# 33  Nanyang Technological UniversityNational Unive...
# 34  Nanyang Technological UniversityNational Unive...
# 35  Nanyang Technological UniversityNational Unive...
# 36                    Career prospects were not found
# 37  Nanyang Technological University&#160;Bachelor...
# 38  Content Developer&#160;Cinematographer&#160;Di...
# 39  Advertising Executive&#160;Content Producer&#1...
# 40  2D/3D Artist&#160;Assistant Designer&#160;Assi...
# NP Course data loaded from storage

# %% [markdown]
# # Nanyang Polytechnic (NYP)

# %%
def search_course_url(row):
    query = f"full-time-courses {row['Course Name']} ({row['Course Code']}) {row['University']}"
    #print(query)
    try:
        num_page = 1
        search_results = ddg(query, max_results=1)
        if search_results:
            #print(search_results)
            #print(search_results[0]['href'])
            return search_results[0]['href']

    except Exception as e:
        print(e)
        return "No results found"


# Function to clean course URLs and extract descriptions
def url_course_desc_scrap(df):
    # Lists to store cleaned URLs, course descriptions, and career prospects
    cleaned_urls = []
    course_descriptions = []
    career_prospects = []

    for index, row in df.iterrows():
        # Search for the course URL
        course_url = search_course_url(row)

        if course_url == "No results found":
            cleaned_urls.append(course_url)
            course_descriptions.append("Course URL not found")
            career_prospects.append("Course URL not found")
            print("Failed: ALL")
        else:
            # Split the URL by '/' and keep only the first 7 components

            cleaned_urls.append(course_url)

            webpage = requests.get(course_url,headers = {'User-agent': 'your bot 0.1'})

            if webpage.status_code == 200:
                soup = BeautifulSoup(webpage.content, "html.parser")
                dom = etree.HTML(str(soup))

                # Define a regex pattern to match HTML tags
                html_tag_pattern = re.compile(r'<[^>]*>')

                # Use XPath to select the parent <p> element that contains the <strong> element for course descriptions
                description = dom.xpath('/html/body/div[1]/div[4]/main/div/div/div[2]/section/div/div[1]/div/div/ul')
                if description:
                    # Extract the text from the selected <p> element and its children
                    paragraph_text = etree.tostring(description[0], method='html').decode()
                    cleaned_text = re.sub(html_tag_pattern, '', paragraph_text)
                    course_descriptions.append(cleaned_text)
                    print("Success: Description")
                else:
                    course_descriptions.append("Course description was not found")
                    print("Failed: Description")

                # Use XPath to select the parent <p> element that contains the career prospects
                prospect = dom.xpath("/html/body/div[1]/div[4]/main/div/div/div[8]/section/ul/li[1]/div/div/ul")
                if prospect:
                    # Extract the text from the selected <p> element and its children
                    paragraph_text = etree.tostring(prospect[0], method='html').decode()
                    cleaned_text = re.sub(html_tag_pattern, '', paragraph_text)
                    career_prospects.append(cleaned_text)
                    print("Success: Prospect")
                else:
                    print("Failed: Prospect")
                    career_prospects.append("Career prospects were not found")
            else:
                print("Failed: Prospect+description")
                cleaned_urls.append(course_url)
                course_descriptions.append("Course URL not found")
                career_prospects.append("Career prospects were not found")

    # Add the cleaned URLs, course descriptions, and career prospects to the DataFrame
    df["Course URL"] = cleaned_urls
    df["Course Description"] = course_descriptions
    df["Career Prospect"] = career_prospects
    
def nyp_scrap():
    try: 
        # Create a dictionary to map courses to their respective categories
        course_category_mapping = {
            'APPLIED CHEMISTRY': 'APPLIED SCIENCES',
            'BIOLOGICS & PROCESS TECHNOLOGY': 'APPLIED SCIENCES',
            'CHEMICAL & PHARMACEUTICAL TECHNOLOGY': 'APPLIED SCIENCES',
            'COMMON SCIENCE PROGRAMME': 'APPLIED SCIENCES',
            'FOOD SCIENCE & NUTRITION': 'APPLIED SCIENCES',
            'PHARMACEUTICAL SCIENCE': 'APPLIED SCIENCES',
            'ARCHITECTURE': 'BUILT ENVIRONMENT',
            'ACCOUNTANCY & FINANCE': 'BUSINESS & MANAGEMENT',
            'BANKING & FINANCE': 'BUSINESS & MANAGEMENT',
            'BUSINESS MANAGEMENT': 'BUSINESS & MANAGEMENT',
            'COMMON BUSINESS PROGRAMME': 'BUSINESS & MANAGEMENT',
            'FOOD & BEVERAGE BUSINESS': 'BUSINESS & MANAGEMENT',
            'HOSPITALITY & TOURISM MANAGEMENT': 'BUSINESS & MANAGEMENT',
            'MASS MEDIA MANAGEMENT': 'BUSINESS & MANAGEMENT',
            'SPORT & WELLNESS MANAGEMENT': 'BUSINESS & MANAGEMENT',
            'BUSINESS & FINANCIAL TECHNOLOGY': 'BUSINESS & MANAGEMENT',
            'ADVANCED & DIGITAL MANUFACTURING': 'ENGINEERING',
            'AERONAUTICAL & AEROSPACE TECHNOLOGY': 'ENGINEERING',
            'AEROSPACE SYSTEMS & MANAGEMENT': 'ENGINEERING',
            'AI & DATA ENGINEERING': 'ENGINEERING',
            'BIOMEDICAL ENGINEERING': 'ENGINEERING',
            'COMMON ENGINEERING PROGRAMME': 'ENGINEERING',
            'ELECTRONIC & COMPUTER ENGINEERING': 'ENGINEERING',
            'ENGINEERING WITH BUSINESS': 'ENGINEERING',
            'INFOCOMM & MEDIA ENGINEERING': 'ENGINEERING',
            'NANOTECHNOLOGY & MATERIALS SCIENCE': 'ENGINEERING',
            'ROBOTICS & MECHATRONICS': 'ENGINEERING',
            'ORAL HEALTH THERAPY': 'HEALTH SCIENCES',
            'NURSING': 'HEALTH SCIENCES',
            'SOCIAL WORK': 'HUMANITIES',
            'APPLIED AI & ANALYTICS': 'INFORMATION & DIGITAL TECHNOLOGIES',
            'COMMON ICT PROGRAMME': 'INFORMATION & DIGITAL TECHNOLOGIES',
            'CYBERSECURITY & DIGITAL FORENSICS': 'INFORMATION & DIGITAL TECHNOLOGIES',
            'INFOCOMM & SECURITY': 'INFORMATION & DIGITAL TECHNOLOGIES',
            'GAME DEVELOPMENT & TECHNOLOGY': 'INFORMATION & DIGITAL TECHNOLOGIES',
            'INFORMATION TECHNOLOGY': 'INFORMATION & DIGITAL TECHNOLOGIES',
            'ARCHITECTURE': 'MEDIA & DESIGN',
            'ANIMATION, GAMES & VISUAL EFFECTS': 'MEDIA & DESIGN',
            'COMMON DESIGN & MEDIA PROGRAMME': 'MEDIA & DESIGN',
            'COMMUNICATION & MOTION DESIGN': 'MEDIA & DESIGN',
            'EXPERIENTIAL PRODUCT & INTERIOR DESIGN': 'MEDIA & DESIGN',
        }


        # Specify the pages you want to extract tables from (for example, page 1)
        pages = [1,2]
        url = "https://www.nyp.edu.sg/content/dam/nyp/admissions/full-time-diploma/admission-exercise/intake-and-jae-elr2b2-points/intake-and-elr2b2.pdf"

        # Extract tables from the PDF file
        tables = tabula.read_pdf(url, pages=pages, multiple_tables=False)
        tables[0].dropna(inplace=True)

        tables[0].columns = ['Course Name', 'Course Code', '2023 Planned Intake', "Range of Net 2023 JAE ELR2B2"]
        tables[0]["University"] = "Nanyang Polytechnic"  # Adding a University column
        tables[0] = tables[0][['University', 'Course Name', 'Course Code', '2023 Planned Intake', "Range of Net 2023 JAE ELR2B2"]]
        
        # Reset the index
        tables[0].reset_index(drop=True, inplace=True)
        # Create a dictionary with the new row data
        new_row_data = {
            'University': 'Nanyang Polytechnic',
            'Course Name': 'NANOTECHNOLOGY & MATERIALS SCIENCE',
            'Course Code': 'C50',
            '2023 Planned Intake': 40,
            'Range of Net 2023 JAE ELR2B2': '10 to 15'
        }

        # Convert the dictionary to a DataFrame
        new_row_df = pd.DataFrame([new_row_data])
        
        # Concatenate the new row DataFrame with the existing combined_df_2
        tables[0] = pd.concat([ tables[0], new_row_df], ignore_index=True)
        
        # Apply the mapping to the 'Course Name' column in your DataFrame
        tables[0]['Course Category'] = tables[0]['Course Name'].map(course_category_mapping)
        
        tables[0] = tables[0][['University',"Course Category", 'Course Name', 'Course Code', '2023 Planned Intake', "Range of Net 2023 JAE ELR2B2"]]
        url_course_desc_scrap(tables[0])

        #display(tables[0])
        tables[0].to_csv("NYP_scrap.csv",index = False)
        return tables[0]
    except Exception as e:
        print(e)

# Debug         
try:
    nyp= pd.read_csv('NYP_scrap.csv') 
    display(nyp)
    print("NYP Course data loaded from storage")
except: 
    print("NYP Course data Scraped from internet")
    nyp  = nyp_scrap()
    display(nyp)
# Out:
#              University                     Course Category  \
# 0   Nanyang Polytechnic                    APPLIED SCIENCES
# 1   Nanyang Polytechnic                    APPLIED SCIENCES
# 2   Nanyang Polytechnic                    APPLIED SCIENCES
# 3   Nanyang Polytechnic                    APPLIED SCIENCES
# 4   Nanyang Polytechnic                    APPLIED SCIENCES
# 5   Nanyang Polytechnic                    APPLIED SCIENCES
# 6   Nanyang Polytechnic                      MEDIA & DESIGN
# 7   Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 8   Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 9   Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 10  Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 11  Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 12  Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 13  Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 14  Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 15  Nanyang Polytechnic               BUSINESS & MANAGEMENT
# 16  Nanyang Polytechnic                         ENGINEERING
# 17  Nanyang Polytechnic                         ENGINEERING
# 18  Nanyang Polytechnic                         ENGINEERING
# 19  Nanyang Polytechnic                         ENGINEERING
# 20  Nanyang Polytechnic                         ENGINEERING
# 21  Nanyang Polytechnic                         ENGINEERING
# 22  Nanyang Polytechnic                         ENGINEERING
# 23  Nanyang Polytechnic                         ENGINEERING
# 24  Nanyang Polytechnic                         ENGINEERING
# 25  Nanyang Polytechnic                         ENGINEERING
# 26  Nanyang Polytechnic                     HEALTH SCIENCES
# 27  Nanyang Polytechnic                     HEALTH SCIENCES
# 28  Nanyang Polytechnic                          HUMANITIES
# 29  Nanyang Polytechnic  INFORMATION & DIGITAL TECHNOLOGIES
# 30  Nanyang Polytechnic  INFORMATION & DIGITAL TECHNOLOGIES
# 31  Nanyang Polytechnic  INFORMATION & DIGITAL TECHNOLOGIES
# 32  Nanyang Polytechnic  INFORMATION & DIGITAL TECHNOLOGIES
# 33  Nanyang Polytechnic  INFORMATION & DIGITAL TECHNOLOGIES
# 34  Nanyang Polytechnic  INFORMATION & DIGITAL TECHNOLOGIES
# 35  Nanyang Polytechnic                      MEDIA & DESIGN
# 36  Nanyang Polytechnic                      MEDIA & DESIGN
# 37  Nanyang Polytechnic                      MEDIA & DESIGN
# 38  Nanyang Polytechnic                      MEDIA & DESIGN
# 39  Nanyang Polytechnic                      MEDIA & DESIGN
# 40  Nanyang Polytechnic                         ENGINEERING
#
#                                Course Name Course Code  2023 Planned Intake  \
# 0                        APPLIED CHEMISTRY         C45                   23
# 1           BIOLOGICS & PROCESS TECHNOLOGY         C49                   23
# 2     CHEMICAL & PHARMACEUTICAL TECHNOLOGY         C73                   88
# 3                 COMMON SCIENCE PROGRAMME         C27                  116
# 4                 FOOD SCIENCE & NUTRITION         C69                   45
# 5                   PHARMACEUTICAL SCIENCE         C65                   59
# 6                             ARCHITECTURE         C38                   54
# 7                    ACCOUNTANCY & FINANCE         C98                   69
# 8                        BANKING & FINANCE         C96                   66
# 9                      BUSINESS MANAGEMENT         C94                  248
# 10               COMMON BUSINESS PROGRAMME         C34                  256
# 11                FOOD & BEVERAGE BUSINESS         C46                   66
# 12        HOSPITALITY & TOURISM MANAGEMENT         C67                   60
# 13                   MASS MEDIA MANAGEMENT         C93                   54
# 14             SPORT & WELLNESS MANAGEMENT         C81                   45
# 15         BUSINESS & FINANCIAL TECHNOLOGY         C35                   98
# 16        ADVANCED & DIGITAL MANUFACTURING         C62                   64
# 17     AERONAUTICAL & AEROSPACE TECHNOLOGY         C51                   41
# 18          AEROSPACE SYSTEMS & MANAGEMENT         C52                   41
# 19                   AI & DATA ENGINEERING         C31                   40
# 20                  BIOMEDICAL ENGINEERING         C71                   40
# 21            COMMON ENGINEERING PROGRAMME         C42                  424
# 22       ELECTRONIC & COMPUTER ENGINEERING         C89                   83
# 23               ENGINEERING WITH BUSINESS         C41                   41
# 24            INFOCOMM & MEDIA ENGINEERING         C75                  130
# 25                 ROBOTICS & MECHATRONICS         C87                   64
# 26                     ORAL HEALTH THERAPY         C72                   25
# 27                                 NURSING         C97                  800
# 28                             SOCIAL WORK         C47                   45
# 29                  APPLIED AI & ANALYTICS         C43                   63
# 30                    COMMON ICT PROGRAMME         C36                  148
# 31       CYBERSECURITY & DIGITAL FORENSICS         C54                   82
# 32                     INFOCOMM & SECURITY         C80                   55
# 33           GAME DEVELOPMENT & TECHNOLOGY         C70                   86
# 34                  INFORMATION TECHNOLOGY         C85                  108
# 35                            ARCHITECTURE         C38                   54
# 36       ANIMATION, GAMES & VISUAL EFFECTS         C29                  125
# 37         COMMON DESIGN & MEDIA PROGRAMME         C28                  132
# 38           COMMUNICATION & MOTION DESIGN         C30                   83
# 39  EXPERIENTIAL PRODUCT & INTERIOR DESIGN         C32                  110
# 40      NANOTECHNOLOGY & MATERIALS SCIENCE         C50                   40
#
#    Range of Net 2023 JAE ELR2B2  \
# 0                       4 to 10
# 1                       5 to 10
# 2                       7 to 14
# 3                       8 to 12
# 4                       5 to 12
# 5                       6 to 10
# 6                       7 to 15
# 7                       6 to 12
# 8                       5 to 12
# 9                       6 to 15
# 10                      5 to 15
# 11                      5 to 16
# 12                      7 to 17
# 13                      6 to 12
# 14                     11 to 17
# 15                      8 to 15
# 16                     15 to 23
# 17                      6 to 16
# 18                     11 to 18
# 19                      3 to 10
# 20                      6 to 14
# 21                      6 to 24
# 22                      3 to 15
# 23                      6 to 14
# 24                     14 to 19
# 25                      6 to 19
# 26                      5 to 10
# 27                     6 to 28*
# 28                      4 to 13
# 29                       4 to 9
# 30                      4 to 14
# 31                      5 to 10
# 32                     11 to 15
# 33                      4 to 11
# 34                      8 to 13
# 35                      7 to 15
# 36                      4 to 10
# 37                      4 to 14
# 38                      4 to 15
# 39                      5 to 17
# 40                     10 to 15
#
#                                            Course URL  \
# 0   https://www.nyp.edu.sg/schools/sas/full-time-c...
# 1   https://www.nyp.edu.sg/schools/sas/full-time-c...
# 2   https://www.nyp.edu.sg/schools/sas/full-time-c...
# 3   https://www.nyp.edu.sg/schools/sas/full-time-c...
# 4   https://www.nyp.edu.sg/schools/sas/full-time-c...
# 5   https://www.nyp.edu.sg/schools/sas/full-time-c...
# 6   https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 7   https://www.nyp.edu.sg/schools/sbm/full-time-c...
# 8   https://www.nyp.edu.sg/schools/sbm/full-time-c...
# 9   https://www.nyp.edu.sg/schools/sbm/full-time-c...
# 10  https://www.nyp.edu.sg/schools/sbm/full-time-c...
# 11  https://www.nyp.edu.sg/schools/sbm/full-time-c...
# 12  https://www.nyp.edu.sg/schools/sbm/full-time-c...
# 13  https://www.nyp.edu.sg/schools/sbm/full-time-c...
# 14  https://www.nyp.edu.sg/schools/sbm/full-time-c...
# 15  https://www.nyp.edu.sg/schools/sit/full-time-c...
# 16  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 17  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 18  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 19  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 20  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 21  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 22  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 23  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 24  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 25  https://www.nyp.edu.sg/schools/seg/full-time-c...
# 26  https://www.nyp.edu.sg/schools/shss/full-time-...
# 27  https://www.nyp.edu.sg/schools/shss/full-time-...
# 28  https://www.nyp.edu.sg/schools/shss/full-time-...
# 29  https://www.nyp.edu.sg/schools/sit/full-time-c...
# 30  https://www.nyp.edu.sg/schools/sit/full-time-c...
# 31  https://www.nyp.edu.sg/schools/sit/full-time-c...
# 32  https://www.nyp.edu.sg/schools/sit/full-time-c...
# 33  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 34  https://www.nyp.edu.sg/schools/sit/full-time-c...
# 35  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 36  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 37  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 38  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 39  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 40  https://www.nyp.edu.sg/schools/seg/full-time-c...
#
#                                    Course Description  \
# 0   \nImpact lives by creating innovative chemical...
# 1   \nShine at the frontline of cutting-edge biolo...
# 2   \nCraft innovative and green solutions to impr...
# 3                    Course description was not found
# 4   \nImprove the well-being of the community thro...
# 5   \nFight against the pandemic and other disease...
# 6                    Course description was not found
# 7   \nHone your competencies in emerging areas tha...
# 8   \nLearn from industry leaders such as DBS Bank...
# 9                    Course description was not found
# 10                   Course description was not found
# 11  \nExperience an interdisciplinary course that ...
# 12  \nAcquire industry-ready skills through undert...
# 13  \nCreate engaging content for audiences across...
# 14  \nFuel your passion for sport, active lifestyl...
# 15                   Course description was not found
# 16                   Course description was not found
# 17                   Course description was not found
# 18                   Course description was not found
# 19                   Course description was not found
# 20                   Course description was not found
# 21                   Course description was not found
# 22                   Course description was not found
# 23                   Course description was not found
# 24  \nSoftware &amp; Applications\nCloud Infrastru...
# 25                   Course description was not found
# 26                   Course description was not found
# 27                   Course description was not found
# 28                   Course description was not found
# 29                   Course description was not found
# 30                   Course description was not found
# 31                   Course description was not found
# 32                   Course description was not found
# 33                   Course description was not found
# 34                   Course description was not found
# 35                   Course description was not found
# 36                   Course description was not found
# 37                   Course description was not found
# 38                   Course description was not found
# 39                   Course description was not found
# 40                   Course description was not found
#
#                                       Career Prospect
# 0   \nAnalytical Chemist\nAssociate Scientist\nFor...
# 1   \nLaboratory Analyst\nManufacturing Biotechnol...
# 2   \nAssistant Process Engineer\nLaboratory Analy...
# 3                     Career prospects were not found
# 4   \nDietetic Assistant\nFood Hygiene Officer\nFo...
# 5   \nClinical Research Coordinator\nPharmaceutica...
# 6                     Career prospects were not found
# 7                     Career prospects were not found
# 8                     Career prospects were not found
# 9                     Career prospects were not found
# 10                    Career prospects were not found
# 11                    Career prospects were not found
# 12                    Career prospects were not found
# 13                    Career prospects were not found
# 14  \nCommunity/Sport &amp; Recreation Executive\n...
# 15                    Career prospects were not found
# 16                    Career prospects were not found
# 17                    Career prospects were not found
# 18                    Career prospects were not found
# 19  \nData Engineers/Technicians\nAI Application D...
# 20                    Career prospects were not found
# 21                    Career prospects were not found
# 22                    Career prospects were not found
# 23                    Career prospects were not found
# 24  \nMobile Apps Developer\nMobile Apps Designer\...
# 25                    Career prospects were not found
# 26                    Career prospects were not found
# 27                    Career prospects were not found
# 28                    Career prospects were not found
# 29  \nAI Data Analyst\nAI Data Engineer\nAI Softwa...
# 30                    Career prospects were not found
# 31                    Career prospects were not found
# 32                    Career prospects were not found
# 33                    Career prospects were not found
# 34                    Career prospects were not found
# 35                    Career prospects were not found
# 36                    Career prospects were not found
# 37                    Career prospects were not found
# 38                    Career prospects were not found
# 39                    Career prospects were not found
# 40                    Career prospects were not found
# NYP Course data loaded from storage

# %% [markdown]
# # Scrap Historical Data

# %%
def remove_asterisk_and_convert(value):
    try:
        # Check if the value contains an asterisk
        if '*' in value:
            # Remove the asterisk and convert to an integer
            return int(value.replace('*', ''))
        else:
            # Convert to an integer directly
            return int(value)
    except ValueError:
        # Handle non-integer values (e.g., if the value cannot be converted)
        return None
    
def historical_scrap():
    # Replace the URL with the URL of your published Google Sheets document
    url = "https://docs.google.com/spreadsheets/d/14b5VLIr9W5teiOp0vCg86B6xxpFiwk8jeIzwbdJmWjU/pubhtml#"

    # Use pandas to read tables from the HTML URL
    tables = pd.read_html(url)

    # Initialize an empty list to store formatted tables
    formatted_tables = []

    # Iterate through the extracted tables (if there are multiple)
    for i, table in enumerate(tables):
        if i > 0:
            # Drop the specified columns
            columns_to_drop = [0, 3, 4, 16, 17, 18, 19]
            table = table.drop(columns=table.columns[columns_to_drop])

            # Filter rows based on the length of the values in the first column
            table = table[table.iloc[:, 0].str.len() <= 3]

            # Rename columns
            table.columns = ['Course Code', 'Course Name',"2023 Planned Intake", "Cutoff 2023", "Cutoff 2022", "Cutoff 2021",
                             "Cutoff 2020", "Cutoff 2019", "Cutoff 2018", "Cutoff 2017", "Cutoff 2016", "Cutoff 2015", "Cutoff 2014"]

            # Convert "Cutoff 2023" column to numeric, coerce non-numeric values to NaN
            table['2023 Planned Intake'] = pd.to_numeric(table['2023 Planned Intake'], errors='coerce')

            # Drop rows with non-integer "Cutoff 2023" values
            table = table.dropna(subset=['2023 Planned Intake'], how='any')
            #display(table)
            # Convert cutoff columns to numeric, handling non-numeric values as NaN
            cutoff_columns = ['Cutoff 2023', 'Cutoff 2022', 'Cutoff 2021', 'Cutoff 2020', 'Cutoff 2019',
                              'Cutoff 2018', 'Cutoff 2017', 'Cutoff 2016', 'Cutoff 2015', 'Cutoff 2014']
            # Apply the custom function to the column
            table[cutoff_columns] = table[cutoff_columns].applymap(remove_asterisk_and_convert)

            table[cutoff_columns] = table[cutoff_columns].apply(pd.to_numeric, errors='ignore')

            
            # Calculate mean, median, and mode for each row from 'Cutoff 2023' to 'Cutoff 2014'
            table['Mean Cutoff'] = table[cutoff_columns].mean(axis=1)
            table['Median Cutoff'] = table[cutoff_columns].median(axis=1)
            table['Mode Cutoff'] = table[cutoff_columns].mode(axis=1).iloc[:, 0]

            # Replace "Course Code" for "NAUTICAL STUDIES" with "DNS"
            table.loc[table['Course Name'] == 'NAUTICAL STUDIES (APPLY VIA DAE ONLY)', 'Course Code'] = 'DNS'

            # Append the formatted table to the list
            formatted_tables.append(table)

    # Concatenate the formatted tables into a single DataFrame
    combined_df_2 = pd.concat(formatted_tables, ignore_index=True)
    combined_df_2['Course Name'] = combined_df_2['Course Name'].str.title()
    
    display(combined_df_2)
    combined_df_2.to_csv("history_scrap.csv",index = False)
    return combined_df_2

# Display the combined DataFrame
# historical = historical_scrap()
# display(historical[historical['Course Code'] =='C97'])
# display(combined_df_2[combined_df_2['Course Code'] == 'DNS'])

# %% [markdown]
# # Combine The Scrapped Courses and Historical Data

# %%
def scrap_all_merge():
    combined_df_1 = pd.concat([sp,tp,rp,np,nyp], axis=0)
    combined_df_1.reset_index(drop=True, inplace=True)
    # Convert "Cutoff 2023" column to numeric, coerce non-numeric values to NaN
    combined_df_1['2023 Planned Intake'] = pd.to_numeric(combined_df_1['2023 Planned Intake'], errors='coerce')

    combined_df_1['Course Name'] = combined_df_1['Course Name'].str.title()

    #display(combined_df_1)
    combined_df_2 = historical_scrap()

    ## Perform an inner join based on the "Course Code" column
    merged_df = pd.merge(combined_df_1, combined_df_2, on="Course Code", how="left")

    # Drop duplicate columns (suffixes are added to duplicate columns)
    #merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()]
    merged_df =merged_df.drop(columns=['Course Name_y','2023 Planned Intake_y'])

    merged_df = merged_df.rename(columns={'2023 Planned Intake_x': '2023 Planned Intake'})
    merged_df = merged_df.rename(columns={'Course Name_x': 'Course Name'})
    
    return merged_df
    # Display the DataFrame
    # display(merged_df)

# %%
try:
    all_courses= pd.read_csv('All_output.csv') 
    display(all_courses.columns)
    print("All Course data loaded from storage")
except: 
    print("Scrapping and creating new dataframe")
    all_courses = scrap_all_merge()
    #os.makedirs('folder/subfolder', exist_ok=True)  
    all_courses.to_csv('All_output.csv',index= False) 
    display(all_courses.columns)
# Out:
# Index(['University', 'Course Category', 'Course Name', 'Course Code',
#        '2023 Planned Intake', 'Range of Net 2023 JAE ELR2B2', 'Course URL',
#        'Course Description', 'Career Prospect', 'Cutoff 2023', 'Cutoff 2022',
#        'Cutoff 2021', 'Cutoff 2020', 'Cutoff 2019', 'Cutoff 2018',
#        'Cutoff 2017', 'Cutoff 2016', 'Cutoff 2015', 'Cutoff 2014',
#        'Mean Cutoff', 'Median Cutoff', 'Mode Cutoff'],
#       dtype='object')
# All Course data loaded from storage

# %%
display(all_courses)
# Out:
#                 University   Course Category  \
# 0    Singapore Polytechnic  APPLIED SCIENCES
# 1    Singapore Polytechnic  APPLIED SCIENCES
# 2    Singapore Polytechnic  APPLIED SCIENCES
# 3    Singapore Polytechnic  APPLIED SCIENCES
# 4    Singapore Polytechnic  APPLIED SCIENCES
# ..                     ...               ...
# 195    Nanyang Polytechnic    MEDIA & DESIGN
# 196    Nanyang Polytechnic    MEDIA & DESIGN
# 197    Nanyang Polytechnic    MEDIA & DESIGN
# 198    Nanyang Polytechnic    MEDIA & DESIGN
# 199    Nanyang Polytechnic       ENGINEERING
#
#                                 Course Name Course Code  2023 Planned Intake  \
# 0                        Applied Chemistry          S64                   75
# 1                       Biomedical Science          S98                   75
# 2                     Chemical Engineering          S70                  120
# 3                 Common Science Programme          S28                  105
# 4                Food Science & Technology          S47                   65
# ..                                      ...         ...                  ...
# 195       Animation, Games & Visual Effects         C29                  125
# 196         Common Design & Media Programme         C28                  132
# 197           Communication & Motion Design         C30                   83
# 198  Experiential Product & Interior Design         C32                  110
# 199      Nanotechnology & Materials Science         C50                   40
#
#     Range of Net 2023 JAE ELR2B2  \
# 0                         4 to 9
# 1                         3 to 7
# 2                        7 to 14
# 3                        3 to 10
# 4                        4 to 11
# ..                           ...
# 195                      4 to 10
# 196                      4 to 14
# 197                      4 to 15
# 198                      5 to 17
# 199                     10 to 15
#
#                                             Course URL  \
# 0    https://www.sp.edu.sg/cls/courses/full-time-di...
# 1    https://www.sp.edu.sg/cls/courses/full-time-di...
# 2    https://www.sp.edu.sg/cls/courses/full-time-di...
# 3    https://www.sp.edu.sg/cls/courses/full-time-di...
# 4    https://www.sp.edu.sg/cls/courses/full-time-di...
# ..                                                 ...
# 195  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 196  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 197  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 198  https://www.nyp.edu.sg/schools/sdm/full-time-c...
# 199  https://www.nyp.edu.sg/schools/seg/full-time-c...
#
#                                     Course Description  \
# 0    \nDiploma in Applied Chemistry (DAPC - S64)Unv...
# 1    \nDiploma in Biomedical Science (DBS - S98)The...
# 2    \nDiploma in Chemical Engineering (DCHE - S70)...
# 3    \nCommon Science Programme (DCSP - S28)Discove...
# 4    \nDiploma in Food Science &amp; Technology (DF...
# ..                                                 ...
# 195                   Course description was not found
# 196                   Course description was not found
# 197                   Course description was not found
# 198                   Course description was not found
# 199                   Course description was not found
#
#                                        Career Prospect  Cutoff 2023  ...  \
# 0    Application Chemist, Assistant Engineer, Chemi...          9.0  ...
# 1                                                               7.0  ...
# 2    Assistant Biotechnologist, Laboratory Analyst,...         14.0  ...
# 3                                     No element Found         10.0  ...
# 4                                                  ,           11.0  ...
# ..                                                 ...          ...  ...
# 195                    Career prospects were not found         10.0  ...
# 196                    Career prospects were not found         14.0  ...
# 197                    Career prospects were not found         15.0  ...
# 198                    Career prospects were not found         17.0  ...
# 199                    Career prospects were not found         15.0  ...
#
#      Cutoff 2020  Cutoff 2019  Cutoff 2018  Cutoff 2017  Cutoff 2016  \
# 0           10.0         10.0         10.0         10.0         10.0
# 1            8.0          7.0          7.0          7.0          7.0
# 2           13.0         13.0         13.0         13.0         12.0
# 3            NaN          NaN          NaN          NaN          NaN
# 4           13.0         12.0         13.0         13.0         14.0
# ..           ...          ...          ...          ...          ...
# 195          NaN          NaN          NaN          NaN          NaN
# 196          NaN          NaN          NaN          NaN          NaN
# 197          NaN          NaN          NaN          NaN          NaN
# 198          NaN          NaN          NaN          NaN          NaN
# 199         16.0         17.0         17.0         17.0         18.0
#
#      Cutoff 2015  Cutoff 2014  Mean Cutoff  Median Cutoff  Mode Cutoff
# 0           11.0         11.0          9.9           10.0         10.0
# 1            8.0          8.0          7.3            7.0          7.0
# 2           12.0         12.0         12.8           13.0         13.0
# 3            NaN          NaN         10.0           10.0         10.0
# 4           14.0         16.0         13.1           13.0         13.0
# ..           ...          ...          ...            ...          ...
# 195          NaN          NaN         10.0           10.0         10.0
# 196          NaN          NaN         14.0           14.0         14.0
# 197          NaN          NaN         15.0           15.0         15.0
# 198          NaN          NaN         17.0           17.0         17.0
# 199         18.0         17.0         16.3           17.0         17.0
#
# [200 rows x 22 columns]

# %% [markdown]
# # Apply Different Filtering approaches

# %% [markdown]
# ## TF-IDF vectorizer Based approach (Applied)

# %%
def preprocess_text(text):
    # Remove special characters and convert to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text.lower())
    
    # Tokenization
    tokens = nltk.word_tokenize(text)
    
    # Remove stopwords and apply stemming
    processed_tokens = [stemmer.stem(token) for token in tokens if token not in stop_words]
    
    # Reconstruct the processed text
    processed_text = ' '.join(processed_tokens)
    
    return processed_text

def filter_courses(merged_df, user_interest, user_score, similarity_threshold=0.5):
    # Preprocess user input
    user_interest = preprocess_text(user_interest)

    # Combine "Course Name" and "Course Category" into a single column
    merged_df['Combined Course Info'] = merged_df['Course Name'] + ' ' + merged_df['Course Category']

    # Apply preprocessing to the 'Combined Course Info' column
    merged_df['Cleaned Combined Info'] = merged_df['Combined Course Info'].apply(preprocess_text)

    # Initialize TF-IDF vectorizer
    tfidf_vectorizer = TfidfVectorizer()

    # Fit and transform the combined course information
    tfidf_matrix = tfidf_vectorizer.fit_transform(merged_df['Cleaned Combined Info'])

    # Transform the user's input
    user_interest_vector = tfidf_vectorizer.transform([user_interest])

    # Calculate cosine similarity between user input and combined course information
    cosine_similarities = cosine_similarity(user_interest_vector, tfidf_matrix).flatten()

    # Add courses with similarity above the threshold to filtered_df
    filtered_df = merged_df[cosine_similarities >= similarity_threshold]

    # Filter further based on user score
    filtered_df = filtered_df[filtered_df['Cutoff 2023'] >= user_score]

    return filtered_df

# %%
# user_interest ="arts"
# user_score = 3
# filer_course_1(all_courses, user_interest,user_score,similarity_threshold = 0.4)

# %% [markdown]
# ## NLP based approach (Not Applied)

# %%
def preprocess_text(text):
    # Remove special characters and convert to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text.lower())
    
    # Tokenization
    tokens = nltk.word_tokenize(text)
    
    # Remove stopwords and apply stemming
    processed_tokens = [stemmer.stem(token) for token in tokens if token not in stop_words]
    
    # Reconstruct the processed text
    processed_text = ' '.join(processed_tokens)
    
    return processed_text

def filter_courses_2(merged_df,user_interest,similarity_threshold = 0.5):
    
    # Load the English language model
    nlp = spacy.load("en_core_web_sm")
    
    # Process the course names and user input
    merged_df['Course Name'] = merged_df['Course Name'].str.lower()
    user_interest = user_interest.lower()
    user_interest_doc = nlp(user_interest)

    # Tokenize and vectorize the user's input
    user_interest_vector = user_interest_doc.vector.reshape(1, -1)

    # Create a list of course name vectors
    course_name_vectors = []

    for course_name in merged_df['Course Name']:
        course_name_doc = nlp(course_name)
        course_name_vector = course_name_doc.vector.reshape(1, -1)
        course_name_vectors.append(course_name_vector)

    # Calculate cosine similarities
    similarities = cosine_similarity(np.vstack(course_name_vectors), user_interest_vector)

    filtered_df = pd.DataFrame(columns=merged_df.columns)
    # Filter courses with similarity scores above the threshold
    filtered_courses = merged_df[similarities.flatten() > similarity_threshold]

    # Add the filtered courses to the filtered_df
    filtered_df = pd.concat([filtered_df, filtered_courses])
    # display(filtered_df)
    # print(len(filtered_df))
    return filtered_df

# %%
# interest_of_studies_input= "Data Science and Machine Learning"
# filter_courses_2(all_courses,interest_of_studies_input,similarity_threshold = 0.8)

# %% [markdown]
# ## Word Vectorized approach (Not applied)

# %%
def filter_courses_3(all_courses,user_input):

    # Load the Word2Vec model
    word_vectors = api.load("word2vec-google-news-300")

    # Function to preprocess text
    def preprocess_text(text):
        text = text.lower()
        text = re.sub(r'[^a-zA-Z\s]', '', text)
        return text

    # Sample user input (replace this with user input)

    user_input = preprocess_text(user_input)

    # Compute word embeddings for user input
    user_words = [word for word in user_input.split() if word in word_vectors]
    if user_words:
        user_vec = np.mean([word_vectors[word] for word in user_words], axis=0)
    else:
        user_vec = None

    # Compute cosine similarity between user input and course descriptions
    if user_vec is not None:
        # Assuming 'all_courses' is your DataFrame with course descriptions
        all_courses["Description"] = all_courses["Course Name"].apply(preprocess_text)
        all_courses["Description"] = all_courses["Description"].apply(
            lambda desc: np.mean([word_vectors[word] for word in desc.split() if word in word_vectors], axis=0)
        )

        all_courses["Similarity"] = all_courses["Description"].apply(
            lambda desc_vec: cosine_similarity([user_vec], [desc_vec])[0][0]
        )

        # Set a similarity threshold
        similarity_threshold = 0.6  # Adjust as needed

        # Filter courses based on similarity
        filtered_courses = all_courses[all_courses["Similarity"] > similarity_threshold]

        # Sort courses by similarity score
        recommended_courses = filtered_courses.sort_values(
            by="Similarity", ascending=False
        )

        # Display recommended courses to the user (customize columns as needed)
        recommended_courses = recommended_courses[[
            'University','Course Category', 'Course Name', 'Course Code', '2023 Planned Intake',
            'Range of Net 2023 JAE ELR2B2', 'Cutoff 2023', 'Cutoff 2022',
            'Cutoff 2021', 'Cutoff 2020', 'Cutoff 2019', 'Cutoff 2018',
            'Cutoff 2017', 'Cutoff 2016', 'Cutoff 2015', 'Cutoff 2014',
            'Mean Cutoff', 'Median Cutoff', 'Mode Cutoff', 'Similarity'
        ]]

        display(recommended_courses)
    else:
        print("No relevant words in user input.")

# %% [markdown]
# # This cell will run generate the output

# %%
import pandas as pd
import ipywidgets as widgets

# Define input widgets
elr2b2_input = widgets.IntSlider(
    value=15,
    min=5,
    max=35,
    step=-1,
    description='',
    layout=widgets.Layout(width='200px')
)

elr2b2_label = widgets.Label("ELR2B2 (O Levels Score):")
elr2b2_box = widgets.VBox([elr2b2_label, elr2b2_input])

cca_score_input = widgets.IntSlider(
    value=0,
    min=0,
    max=2,
    step=1,
    description='',
    layout=widgets.Layout(width='200px')
)

cca_score_label = widgets.Label("CCA Score:")
cca_score_box = widgets.VBox([cca_score_label, cca_score_input])

interest_of_studies_input = widgets.SelectMultiple(
    options=["Computing","Aviation", 'Computer & Information Technology', 'Business', "AI", "Arts", "Management", "Data Science", "Mechanical", "Game", "Design"],
    value=['Computer & Information Technology'],
    description='Interest of\nStudies:'
)

# Define a submit button
submit_button = widgets.Button(description='Submit')

# Define output widgets
output_table = widgets.Output()

# Function to handle the submit button click event
def on_submit_button_click(b, similarity=0.5):
    with output_table:
        # Clear previous output
        output_table.clear_output()
        
        # Validate ELR2B2 input
        elr2b2_value = elr2b2_input.value
        if not (5 <= elr2b2_value <= 35):
            Javascript("alert('Invalid ELR2B2 input. Please enter a value between 5 and 35.');")
            return
        
        # Validate CCA Score input
        cca_score_value = cca_score_input.value
        if not (0 <= cca_score_value <= 2):
            Javascript("alert('Invalid CCA Score input. Please enter a value between 0 and 2.');")
            return

        # Calculate user score
        user_score = elr2b2_value - cca_score_value
        
        all_filtered_courses = pd.DataFrame(columns=all_courses.columns)
        #print(all_courses.columns)

        for interest in list(interest_of_studies_input.value):
            # Filter the recommended courses based on user score
            filtered_courses = filter_courses(all_courses, interest, user_score, 0.3)
            all_filtered_courses = pd.concat([all_filtered_courses, filtered_courses])
        
        # Display the filtered courses as a DataFrame
        if not all_filtered_courses.empty:
            # Assuming 'all_filtered_courses' is your DataFrame
            all_filtered_courses.rename(columns={'University': 'Polytechnic'}, inplace=True)
            all_filtered_courses.rename(columns={'Course Category': 'School Name'}, inplace=True)
            

            # Columns to consider
            cutoff_columns = ['Cutoff 2014', 'Cutoff 2015', 'Cutoff 2016', 'Cutoff 2017', 'Cutoff 2018',
                              'Cutoff 2019', 'Cutoff 2020', 'Cutoff 2021', 'Cutoff 2022', 'Cutoff 2023']
            #print(cutoff_columns)
            # Extract the years (column names) and their corresponding cutoff values
            # Plot course cutoff scores over the years
            display(all_filtered_courses[
                ['Polytechnic','School Name', 'Course Name', 'Course Code', '2023 Planned Intake',
                'Range of Net 2023 JAE ELR2B2', 'Cutoff 2023','Mean Cutoff', 'Median Cutoff', 'Mode Cutoff', 
                'Course URL','Course Description', 'Career Prospect']])
            for index, row in all_filtered_courses.iterrows():

                years = [year.split()[-1] for year in cutoff_columns]
                cutoff_values = [row[year] for year in cutoff_columns]

                # Create a line graph for each course
                plt.figure(figsize=(12, 6))
                plt.plot(years, cutoff_values, marker='o', linestyle='-', color='b')
                plt.title(f"Cutoff Scores Over the Years for {row['Course Name']}")
                plt.xlabel("Year")
                plt.ylabel("Cutoff Score")
                plt.grid(True)
                plt.show()
        else:
            print("No courses match your criteria.")

# Set the function to be called when the submit button is clicked
submit_button.on_click(on_submit_button_click)

# Display the input widgets and submit button
input_widgets = widgets.HBox([elr2b2_box, cca_score_box, interest_of_studies_input, submit_button])
display(input_widgets)

# Display the output table
display(output_table)
# Out:
# HBox(children=(VBox(children=(Label(value='ELR2B2 (O Levels Score):'), IntSlider(value=15, layout=Layout(width…
# Output()
